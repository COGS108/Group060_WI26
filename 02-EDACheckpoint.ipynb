# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# ## Authors
# - Inigrid Wang: Research Question, Background, Data - Description, Merged Table, EDA - Search Interest (all countries & US)
# - John Bolibol: Hypothesis, Ethics, Data - TMDb API, EDA - Media Exposure
# - Nathan Bustos Medina: Prior Work, Data - Google Trends, EDA - Search Interest (Japan)
# - Sophia Xie: Team Expectations, Data - IP Creation Date, EDA - Creation Date (all country & US)
# - Szeying Chan: Timeline, Data - IP Global Revenue, EDA - Creation Date (Japan)

# %% [markdown]
# # Research Question

# %% [markdown]
# Given the US’s deep integration with global popular culture - particularly Japanese IPs - how do factors like the creation date of IPs, consumer engagement, and media exposure correlate with historical IP performance in the global market? We measure IP performance by the individual IP's cumulative global revenue, consumer engagement by these IP's cumulative search interest worldwide, and media exposure by the number of streaming platforms that carry content from that IP. Furthermore, when we look at US and Japanese IPs separately, how do these different factors contribute to their cumulative global revenue?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# While the US is one of the major entertainment markets in the world, its entertainment market is becoming increasingly dependent on imported IPs, which is evident as we see a 17.9% increase in the US demand for imported content in film and TV shows from 2019 to 2025.<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2) A contributer to this demand is Japanese IPs. Japan is known for its sustaining IPs, which can be seen with franchises such as Pokémon and One Piece that continue to have major commericial success even through the decades since these series have been released. In fact, Japan‘s anime market alone generated billions of dollars in annual revenue by the mid-2020s, and is still expected to grow due to domestic and international demand.<a name="cite_ref-4"></a>[<sup>4</sup>](#cite_note-4)
#
# This raises questions about the strength of domestic US IPs, including major franchises such as Disney and Marvel. With the increasingly globalized U.S. popular culture, American consumers are continuously attracted to foreign media such as anime, gearing their attention away from domestic IPs. This drives us to explore which how the three factors that we have identified in our research question contribute (possibly differently) to the cumulative global revenue of these IPs.
#
# There are no prior studies known to us that are directly related to our project. However, we did find some studies that can provide insight into the conclusion of our study. In 2025, the cultural differences between the marketing strategies by the United States vs the Japanese were explored.<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1) The findings exhibited that the US marketing strategies included an emphasis on bold self-expression and straight-forward, relatable advertising tactics. On the other hand, Japanese marketing tactics put more focus on storytelling, culture, family, and simplicity. They also focus on highlighting the craftsmanship and quality of their products. This may have some relation to the importance of brand loyalty in Japan compared to America. This emphasis on long-term relationships can be seen through the long-lasting dominance of brands such as Sony and Nintendo in Japanese society–and even amongst many Americans.
#
# Research exploring the behavior of both American and Japanese children and their relationship with advertisement showed that there were many differences between the two audiences.<a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3) In America, the children were more skeptical towards the advertisements and are more susceptible to direct messaging and reasoning. They also are more attracted to products that market towards the benefits of a child. In Japan, children are more vulnerable to advertisements and watch much less television. This means it is harder for them to recognize when something is an advertisement. Japanese children are more susceptible to emotional messaging that puts a larger emphasis towards the product benefitting their family’s needs.
#
# Two years ago, the Japanese IP-driven Merchandising Market in only the United States was roughly valued at 19.2 Billion USD and has been projected to grow at a CAGR (Compound Annual Growth Rate) of 11.7 percent.<a name="cite_ref-5"></a>[<sup>5</sup>](#cite_note-5) The catalyst of this significant rise would be the increased popularization of anime in streaming platforms like Netflix, Crunchyroll and Hulu. Meanwhile, out of the top 10 global licensors of 2025, 8 out of 10 of the companies were American.<a name="cite_ref-6"></a>[<sup>6</sup>](#cite_note-6) This includes the titan that is Disney–reaching 62 Billion USD globally.
#
# **Resources**
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Cox, E. (2025, July 7). Understanding the Cultural Differences in Marketing: U.S. vs. Japan | Hapatune. Hapatune. https://hapatune.com/understanding-the-cultural-differences-in-marketing-u-s-vs-japan/‌
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Flynn, K. (6 Dec 2025). U.S. demand for foreign films and shows hits all-time high. https://www.axios.com/media-trends-membership/2025/12/06/foreign-tv-streaming-demand
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) Gaumer, C., & Shah, A. (2004). Television Advertising and Child Consumer: Different Strategies for U.S. and Japanese Marketers. The Coastal Business Journal the Coastal Business Journal, 3(1), 3. https://digitalcommons.coastal.edu/cgi/viewcontent.cgi?article=1027&context=cbj
# 4. <a name="cite_note-4"></a> [^](#cite_ref-4) Grand View Research. (2025). Japan anime merchandising market size, share & trends analysis. https://www.grandviewresearch.com/press-release/japan-anime-merchandising-market-analysis
# 5. <a name="cite_note-5"></a> [^](#cite_ref-5) Japanese IP-driven Merchandise And Content Market, 2030. (2024). Grandviewresearch.com. https://www.grandviewresearch.com/industry-analysis/japanese-ip-driven-merchandise-content-market-report
# 6. <a name="cite_note-6"></a> [^](#cite_ref-6) License Global. (2023, July 27). The Top Global Licensors Report 2023 | LicenseGlobal. Www.licenseglobal.com. https://www.licenseglobal.com/rankings-lists/top-150-leading-licensors

# %% [markdown]
# # Hypothesis

# %% [markdown]
# Generally, we think that consumer engagement is most important and will correlate the strongest with the cumulative global revenue of IPs, because engaged customers spend more money on an IP. In our project, an old creation date does not necessarily mean high engagement over time, and media exposure through airing platforms only gives a chance for fans to be engaged, while search interest reflects engagement more directly.
#
# When we focus on US IPs, we expect media exposure to correlate the strongest with the global revenue of IPs for a simple reason——most US IPs are heavily dependent on TV/film adaptation when it comes to making money at a large scale.
#
# When we focus on Japanese IPs, we expect IP creation date to correlate the strongest with the global revenue of Japanese IPs. We reason this because of the following: Japanese IPs are famous for their serialized mangas. Creating manga pairs high labor demand with a low budget for workers, which means that progressing the same amount in story would take longer through a manga than with film. This often causes an IP created through manga to stay long-running, providing more time to sell merchandize and their corresponding anime to run even longer than the manga itself, which allows Japanese IPs take a stronger advantage of peak popularity and have more chances at peak popularity if the IP cools down for some periods (lower dependence on a few peak consumer engagement) when it comes to cumulative global revenue. Manga, given that it is graphic, gains popularity fairly easily in the main entertainment markets (US, Japan, China, and Korea); note that Japan, China, and Korea all share similar aspects of culture through historical ties and their respective entertainment industries all have a very active manga/manhwa/webtoon community. This characteristic of the manga medium allows Japanese IPs to gain significant popularity even before being adapted into TV/film (lowering dependence on media exposure).

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
# - Dataset #1
#   - Dataset Name: Worldwide search interest of top 27 highest-grossing Japanese IPs and US IPs
#   - Note: We requested the data ourselves from Google Trends at the link https://trends.google.com/trends/. Google Trends
#     returned the data as a csv. We stored the csv on the repository belonging to a member of our team (username: spiianch).
#   - Link to the dataset: https://raw.githubusercontent.com/spiianch/cogs108_googletrends27/refs/heads/main/cogs108_googletrends27%20-%20time_series_Worldwide_20031231-1600_20260301-0149.csv
#   - Number of observations: 14098
#   - Number of variables: 3
#   - Description of the variables most relevant to this project:
#         Variables—Topic name, week, search interest.
#         We are using worldwide data from 2004-present, with 2004 being the earliest time that Google Trends can track.
#         The search interest ranges from 0-100 instead of exact counts because Google Trends normalizes search interest for
#         specific topics (IPs in our case) to its peak in the timeframe we specify, where 100 is the highest level of interest
#         and 0 is the lowest. Each row of data shows the search interest that month.
#
# - Dataset #2
#   - Dataset Name: Japanese IP Global Revenue & Creation Date
#   - Link to the dataset: https://en.wikipedia.org/wiki/List_of_highest-grossing_media_franchises#cite_note-270
#   - Number of observations: 27
#   - Number of variables: 3
#   - Description of the variables most relevant to this project:
#     Variables—IP name, global revenue in USD, and creation date.
#     The link we provided ranks the top grossing Japanese IPs by their cumulative global revenue. All
#     the variables included in the dataset are franchise, year, revenue in billions of dollars, original medium that the IP was
#     published in, and the owner of the IP.
#
# - Dataset #3
#   - Dataset Name: US IP Global Revenue & Creation Date
#   - Link to the dataset: https://en.wikipedia.org/wiki/List_of_highest-grossing_media_franchises#cite_note-270
#   - Number of observations: 27
#   - Number of variables: 3
#   - Description of the variables most relevant to this project:
#     Variables—IP name, global revenue in USD, and creation date.
#     The link we provided ranks the top grossing US IPs by their cumulative global revenue. All
#     the variables included in the dataset are franchise, year, revenue in billions of dollars, original medium that the IP was
#     published in, and the owner of the IP.
#
# - Dataset #4
#   - Dataset Name: Global number of streaming platforms carrying an IP
#   - Note: Data were collected using the TMDb API. Broad IPs (e.g., Disney Princess, Marvel) were broken down into their individual films and television series to improve search results. Franchises with multiple movies or seasons were further expanded using different official titles to capture all relevant entries.
#   - Number of observations: 19
#   - Number of variables: 2
#   - Description of key variables: This project focuses on two variables: the IP name and how many streaming platforms carry content from that IP. The number of platforms is used as a measure of how accessible each IP is to viewers.
#   - Descriptions of any shortcomings this dataset has with respect to the project:
#     This dataset was created using the TMDb API rather than downloaded directly, so it depends on how complete and accurate TMDb’s information is. Some search results may be loosely related to an IP, which adds noise to the data. Streaming provider information is also missing for some IPs, especially non-U.S. content. For example, Rilakkuma has limited provider data in TMDb despite being available on major streaming platforms, which may lead to its accessibility being underestimated.

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- Run only once after cloning!!! 
#
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pearsonr, spearmanr

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://raw.githubusercontent.com/fivethirtyeight/data/refs/heads/master/airline-safety/airline-safety.csv', 'filename':'airline-safety.csv'},
    { 'url': 'https://raw.githubusercontent.com/fivethirtyeight/data/refs/heads/master/bad-drivers/bad-drivers.csv', 'filename':'bad-drivers.csv'},
    { 'url': 'https://raw.githubusercontent.com/spiianch/cogs108_googletrends27/refs/heads/main/cogs108_googletrends27%20-%20time_series_Worldwide_20031231-1600_20260301-0149.csv', 'filename' : 'cogs108_googletrends27.csv'}
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')
# Out:
# ...
# Overall Download Progress:  33%|██████            | 1/3 [00:00<00:00,  5.38it/s]
# Successfully downloaded: airline-safety.csv
# ...
# Overall Download Progress:  67%|████████████      | 2/3 [00:00<00:00,  4.90it/s]
# Successfully downloaded: bad-drivers.csv
# ...
# Overall Download Progress: 100%|██████████████████| 3/3 [00:00<00:00,  4.75it/s]
# Successfully downloaded: cogs108_googletrends27.csv

# %% [markdown]
# ### Google Trends - measures fan engagement
#
# 1. Interest values (0-100) show relative search interest
#     100 shows the highest search interest. Search interest between 100 and 0 means proportionally fewer
#     searches compared to the peak. 0 means there is not enough data to record significant search volume. Every value in
#     between 0 and 100 is given with respect to the peak.
# 2. Major Concerns: We cannot directly compare the relative search interest across different IPs unless they are pulled in the
#    same query. Google Trends only allows up to query 8 IPs at once since we are requesting all-time data. We addressed this
#    concern by normalizing all queries to one IP and included the same IP across all queries in order to do this.
#    Example:
#   ```
# 7 (distinct) IPs + 1 anchor IP (ex. Pokemon)
# 7 (distinct) IPs + 1 anchor IP (ex. Pokemon)
# 7 (distinct) IPs + 1 anchor IP (ex. Pokemon)
# 7 (distinct) IPs + 1 anchor IP (ex. Pokemon)
# 7 (distinct) IPs + 1 anchor IP (ex. Pokemon)
# 7 (distinct) IPs + 1 anchor IP (ex. Pokemon)
# 7 (distinct) IPs + 1 anchor IP (ex. Pokemon)
# 4 (distinct) IPs + 1 anchor IP (ex. Pokemon)
# ```
#   (7 * 7) + 5 = 53 distinct IPs. 53 + 1 anchor IP = 54 IPs in total (27 each)
#
# Note: No invalid data in Google Trends data, but we will drop all search interest datapoints for Pokemon because it has a very large search interest in comparision with all other IPs.
#
# Justification: we checked the csv file for <1 and NaN values, but we did not find any of these. There are a lot of 0 values, but that is just due to the fact that Pokemon's 100 is quite high compared to every other IP, which causes lower search interests to become 0. 0 in Google Trends does not represent no search interest; it just represents really low search interest compared to the peak of all IPs being compared.
#
# Pokemon has a peak monthly search interest of 100, while the second highest monthly search interest is 59, belonging to another IP. Hence, we see this as an outlier and will drop it from this dataset.

# %%
trends = datafiles[2]['url']
df = pd.read_csv(trends)
df
# Out:
#           Time  PokÃ©mon  Anpanman  Hello Kitty  Pac-Man  Space Invaders  \
# 0     1/1/2004         5         0            1        1               0
# 1     2/1/2004         5         0            1        1               0
# 2     3/1/2004         5         0            1        1               0
# 3     4/1/2004         5         0            1        1               0
# 4     5/1/2004         5         0            1        1               0
# ..         ...       ...       ...          ...      ...             ...
# 261  10/1/2025        10         0            1        1               0
# 262  11/1/2025         8         0            1        1               0
# 263  12/1/2025         7         0            1        1               0
# 264   1/1/2026         4         0            1        1               0
# 265   2/1/2026         5         0            1        1               0
#
#      Dragon Ball  Street Fighter  Rilakkuma  Monster Strike  ...  Peanuts  \
# ...

# %% [markdown]
# Interest Value score is determined relative to "Pokemon" interest from 2004-present. For improved readability, franchises, dates, and interest value will all be put in one column.

# %%
df['Time'] = pd.to_datetime(df['Time'])

df = df.rename(columns={'PokÃ©mon': 'Pokemon'})
df = df.rename(columns={'Fate/stay night': 'Fate (Fate/stay night)'})
df = df.rename(columns={'Grand Theft Auto': 'Grand Theft Auto (GTA)'})
df = df.rename(columns={'Marvel Entertainment': 'Marvel Cinematic Universe (MCU)'})
df = df.rename(columns={'Time': 'Month'})
df = df.rename(columns={'Topic name': 'Franchise'})
df = df.rename(columns={'Search interest': 'Interest Value'})


df_cleaned = df.melt(
    id_vars=['Month'],
    var_name='Franchise',        
    value_name='Interest Value'  
)

df_cleaned = df_cleaned[df_cleaned['Franchise'] != 'Pokemon']
df_cleaned = df_cleaned.sort_values(['Month', 'Franchise']).reset_index(drop=True)

df_cleaned
# Out:
#            Month          Franchise  Interest Value
# 0     2004-01-01        Angry Birds               0
# 1     2004-01-01           Anpanman               0
# 2     2004-01-01          Astro Boy               0
# 3     2004-01-01             Barbie               4
# 4     2004-01-01           Beyblade               1
# ...          ...                ...             ...
# 14093 2026-02-01          Toy Story               1
# 14094 2026-02-01           Ultraman               0
# 14095 2026-02-01  World of Warcraft               3
# 14096 2026-02-01       Yo-Kai Watch               0
# 14097 2026-02-01          Yu-Gi-Oh!               0
#
# [14098 rows x 3 columns]

# %% [markdown]
# ### Japanese IP Global Revenue and Creation Date
# 1. Important metrics, what units they are in, and what they mean:
# > "Franchise" refers to the name of the IP. "Creation Date" means the earliest date that the IP was created when taking different medium presentations into account. "Revenue (Billion USD)" means cumulative global revenue of the IP given in billion USD.
#
# 2. Major concerns with the dataset:
# > A major concern of this dataset is that some cumulative global revenues do not match up with the reported revenues on other sources such as Alibaba. We think think this is because these sources use different references and calculative cumulative global revenue with different metrics. For example, Wikipedia will include box office, merchandize sales, and DVD sales while Alibaba only includes the first two.

# %%
path = '~/Group060_WI26/data/highest_grossing_media_franchises.csv'
df = pd.read_csv(path)
df
# Out:
#                      Franchise  Year  RevenueBillionDollars   Original Medium  \
# 0                      Pokémon  1996                  115.0        Video game
# 1       Mickey Mouse & Friends  1928                   61.2  Animated cartoon
# 2              Winnie the Pooh  1924                   50.2              Book
# 3                    Star Wars  1977                   46.7              Film
# 4              Disney Princess  2000                   45.4    Animated films
# ..                         ...   ...                    ...               ...
# 132  Resident Evil (Biohazard)  1996                    2.0        Video game
# 133                Guitar Hero  2005                    2.0        Video game
# 134                       Lego  1995                    2.0        Video game
# 135                    NBA Jam  1993                    2.0        Video game
# 136    Neon Genesis Evangelion  1994                    2.0             Anime
#
# ...

# %% [markdown]
# The data is pulled directly from the Wikipedia dataset of the highest-grossing media franchises. There are over 130 franchises/IPs from different countries. We will clean the data to only include the top Japanese and US IPs.
#
# While Pokemon is among the 27 Japanese IPs in our dataset, it has a particularly high cumulative global revenue (115 Billion USD) while the IP with the second highest cumulative global revenue is Anpanman at 38.40 Billion USD. Hence, we see this as an outlier and will drop it from this dataset.

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
df = df.rename(columns={"Year": "Creation Date"})
df = df.rename(columns={"Revenue_Billion_USD": "Revenue (Billion USD)"})
df.columns = ["Franchise", "Creation Date", "Revenue (Billion USD)", "Original_Medium", "Owner"]

df["Revenue (Billion USD)"] = pd.to_numeric(df["Revenue (Billion USD)"], errors="coerce")

df_sorted = df.sort_values(by="Revenue (Billion USD)", ascending=False)

japan_franchises = [
    "Anpanman",
    "Hello Kitty",
    "Pac-Man",
    "Dragon Ball",
    "Street Fighter",
    "Demon Slayer: Kimetsu no Yaiba",
    "Yu-Gi-Oh!",
    "Gundam",
    "Monster Strike",
    "Rilakkuma",
    "Ultra Series (Ultraman)",
    "Sonic the Hedgehog",
    "Sailor Moon",
    "Astro Boy",
    "Hamtaro",
    "Fate (Fate/stay night)",
    "Neon Genesis Evangelion",
    "Yo-kai Watch",
    "Super Sentai / Power Rangers",
    "Mario",
    "Space Invaders",
    "Resident Evil (Biohazard)",
    "Beyblade",
    "Gran Turismo",
    "Godzilla (Gojira)",
    "Kumamon"
]

top_japan = df_sorted[df_sorted["Franchise"].isin(japan_franchises)]

top_table_japan = top_japan[["Franchise", "Creation Date", "Revenue (Billion USD)"]].reset_index(drop=True)

top_table_japan
# Out:
#                          Franchise  Creation Date  Revenue (Billion USD)
# 0                         Anpanman           1973                  38.40
# 1                      Hello Kitty           1974                  33.50
# 2                          Pac-Man           1980                  15.43
# 3                   Space Invaders           1978                  13.90
# 4                      Dragon Ball           1984                  10.70
# 5                   Street Fighter           1987                  10.70
# 6                        Rilakkuma           2003                  10.00
# 7                   Monster Strike           2013                  10.00
# 8   Demon Slayer: Kimetsu no Yaiba           2016                  10.00
# 9                            Mario           1981                   8.75
# 10    Super Sentai / Power Rangers           1975                   8.67
# 11         Ultra Series (Ultraman)           1966                   7.40
# ...

# %% [markdown]
# Data cleaned to only include 27 Japanese IPs and their creation dates based off global revenue, as 27 is the maximum amount of Japanese IPs found in the Wikipedia dataset. We are also only using 27 US IPs instead of the 79 total US IPs available to us in the Wikipedia dataset, as our exploratory data analysis on IPs (regardless of country) will be influenced if we have a lot of more datapoints of US IPs in comparison to Japanese IPs. Also, it will be best when using the same amount of IPs when comparing the IPs from the US and Japan separately.
#
# We are not including the IP "Transformers" in any of our wrangled datasets (although it appears on the Wikipedia dataset we are using), as "Transformers" is jointly created by Japan and the US. We checked all IPs that we are using to make sure that they are assigned to their appropriate country.

# %% [markdown]
# ### US IP Global Revenue and Creation Date
#    1. Important metrics, what units they are in, and what they mean:
#    > "Franchise" refers to the name of the IP. "Creation Date" means the earliest date that the IP was created when taking
# different medium presentations into account. "Revenue (Billion USD)" means cumulative global revenue of the IP given in billion USD.
#
#    2. Major Concerns with the dataset:
#    > A major concern of this dataset is that some cumulative global revenues do not match up with the reported revenues on other sources such as Alibaba. We think think this is because these sources use different references and calculative cumulative global revenue with different metrics. For example, Wikipedia will include box office, merchandize sales, and DVD sales while Alibaba only includes the first two.

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
us_franchises = [
    "Star Wars", "Disney Princess", "Barbie", "Marvel Cinematic Universe (MCU)", 
    "Wizarding World (Harry Potter)", "Call of Duty", "Batman", "Spider-Man", "Cars", "Candy Crush", 
    "Looney Tunes", "Teenage Mutant Ninja Turtles", "SpongeBob SquarePants", 
    "The Lion King", "Dora the Explorer", "Paw Patrol", "Toy Story", "Peanuts", 
    "Avengers", "Frozen", "Warcraft", "Despicable Me (Minions)", "Star Trek", 
    "Jurassic Park", "Grand Theft Auto (GTA)", "James Bond", "Angry Birds", 
    "Thomas & Friends", "Fortnite", "Aladdin", "The Incredibles", "Kung Fu Panda", 
    "Winx Club", "The Powerpuff Girls", "Friends", "The Simpsons", "Assassin's Creed", 
    "Mission: Impossible", "The Big Bang Theory", "Seinfeld", "Minecraft", 
    "Twilight", "Gran Turismo", "Strawberry Shortcake", "The Smurfs", "Cabbage Patch Kids", 
    "G.I. Joe", "The Hunger Games", "Blue's Clues", "Beauty and the Beast", "Skylanders", 
    "Titanic", "Titanfall", "Bratz", "Fengshen Cinematic Universe", "Care Bears", "Terminator", 
    "Indiana Jones", "Madagascar", "Captain America", "Rocky", "MonsterVerse", "The Matrix", 
    "The Chronicles of Narnia", "E.T. the Extra-Terrestrial", "Robert Langdon / The Da Vinci Code", 
    "Bourne", "Men in Black", "Guitar Hero", "Lego", "NBA Jam", "Black Panther", "Zootopia (Zootropolis)", 
    "Iron Man", "Guardians of the Galaxy", "Inside Out", "The Elder Scrolls"
]

top27_us = df_sorted[df_sorted["Franchise"].isin(us_franchises)].head(27)

top27_table_us = top27_us[["Franchise", "Creation Date", "Revenue (Billion USD)"]].reset_index(drop=True)

top27_table_us
# Out:
#                           Franchise  Creation Date  Revenue (Billion USD)
# 0                         Star Wars           1977                  46.70
# 1                   Disney Princess           2000                  45.40
# 2                            Barbie           1987                  36.30
# 3   Marvel Cinematic Universe (MCU)           2008                  35.20
# 4    Wizarding World (Harry Potter)           1997                  34.70
# 5                      Call of Duty           2003                  31.00
# 6                            Batman           1939                  29.90
# 7                        Spider-Man           1962                  26.80
# 8                              Cars           2006                  21.50
# 9                       Candy Crush           2012                  20.00
# 10                     Looney Tunes           1930                  17.46
# 11     Teenage Mutant Ninja Turtles           1984                  17.40
# ...

# %% [markdown]
# Data cleaned to only include the top 27 US IPs and their creation dates based off global revenue, to match the 27 Japanese IPs.

# %% [markdown]
# ### Global number of streaming platforms carrying an IP
#    1. Important metrics, what units they are in, and what they mean:
#       >This dataset was created using information from the TMDb API and looks at how easy it is to access different major entertainment franchises. Each row in the dataset represents one IP, such as Marvel, Star Wars, or Rilakkuma. The main metric used in this project is the number of streaming platforms that carry at least one movie or TV show from that IP. This value is a count, measured in number of platforms. The number of streaming platforms is used as a way to measure accessibility. If an IP appears on many platforms, it is easier for people to watch without needing a specific subscription. If it appears on only one or two platforms, it is more limited and harder to access. To calculate this, broad IPs were broken into individual movies and shows, and all streaming providers across those titles were combined.
#
#    3. Major concerns with the dataset:
#    >There are some important limitations to this dataset. The data was collected through many API searches rather than downloaded as a single dataset, so it depends on how complete and accurate TMDb’s information is. Some search results may include titles that are only loosely related to an IP, which adds noise to the data. In addition, streaming provider information is missing for some IPs, especially non-U.S. content. For example, Rilakkuma and Kumamon have limited provider data in TMDb even though it is available on major streaming platforms. Because of this, the accessibility of some IPs may be underestimated, and the results should be viewed as general comparisons instead of exact measurements.
#
#    > NOTE: No invalid data in TMDb API, but there are some noises. Some noise is present in the dataset because certain movies or shows with similar titles (but not officially affiliated with a given IP) may have been included in the results. For example, when we query "Cinderella", there can be other non-Disney Cinderella-related media that have Cinderella in their name. We have to manually exclude these, and there is no way of doing it with code. However, these only make up a minority of all the media that is associated with the IP that we are focusing on. Though, this still means we have to manually check this for 57 different IPs, so we want to make this a limitation instead of actually “cleaning” the TMDb API to exclude them. Despite this limitation, the overall patterns observed should still provide a reasonable approximation of each IP’s relative reach and availability across streaming platforms. Some noise is unavoidable, as titles with similar names that are not officially part of an IP may have been captured during our API searches.

# %%
# The following code was used to obtain the data via the TMDb API on another notebook. 
# Data retrieved using the API was then saved to a csv file and loaded for the checkpoint.
# API.Key is hidden to ensure security of our group member's TMDb account. Minimal data cleaning was done here too. 

#import tmdbsimple as tmdb
#import requests

#tmdb.API_KEY = '7.....9c0dbe4.....d9a4d3'

#There can be more than one airing media associated with an individual IP that we are looking at. Hence, we included 
#all relevant media on the TMDb API that is associated with the IP of interest. For example, Disney Princess can include 
#both Snow White, Ariel, and more princesses.

# Star_Wars = [
#     "Star Wars",
#     "Star Wars: Episode IV - A New Hope",
#     "Star Wars: Episode V - The Empire Strikes Back",
#     "Star Wars: Episode VI - Return of the Jedi",
#     "Star Wars: Episode I - The Phantom Menace",
#     "Star Wars: Episode II - Attack of the Clones",
#     "Star Wars: Episode III - Revenge of the Sith",
#     "Star Wars: Episode VII - The Force Awakens",
#     "Star Wars: Episode VIII - The Last Jedi",
#     "Star Wars: Episode IX - The Rise of Skywalker",
#     "Rogue One: A Star Wars Story",
#     "Solo: A Star Wars Story",
#     "The Mandalorian",
#     "Andor",
#     "Obi-Wan Kenobi",
#     "Ahsoka",
#     "Star Wars: The Clone Wars",
#     "Star Wars Rebels",
#     "The Book of Boba Fett",
#     "Star Wars: The Bad Batch"
# ]

# Disney_Princess = [
#     "Disney Princess",
#     "Disney Princesses",
#     "Snow White and the Seven Dwarfs",
#     "Cinderella",
#     "Sleeping Beauty",
#     "The Little Mermaid",
#     "Beauty and the Beast",
#     "Aladdin",
#     "Pocahontas",
#     "Mulan",
#     "The Princess and the Frog",
#     "Tangled",
#     "Brave",
#     "Moana",
#     "Raya and the Last Dragon",
#     "Frozen",
#     "Frozen II"
# ]

# Barbie = [
#     "Barbie",
#     "Barbie (2023)",
#     "Barbie as the Princess and the Pauper",
#     "Barbie: Fairytopia",
#     "Barbie: Mermaidia",
#     "Barbie and the Magic of Pegasus",
#     "Barbie: Swan Lake",
#     "Barbie: The Princess and the Popstar",
#     "Barbie: A Fashion Fairytale",
#     "Barbie: Princess Charm School",
#     "Barbie: Life in the Dreamhouse",
#     "Barbie Dreamhouse Adventures"
# ]

# Marvel_Cinematic_Universe = [
#     "Marvel Cinematic Universe (MCU)",	
#     "Marvel Cinematic Universe",
#     "MCU",
#     "Marvel Studios",
#     "Iron Man",
#     "The Incredible Hulk",
#     "Iron Man 2",
#     "Thor",
#     "Captain America: The First Avenger",
#     "The Avengers",
#     "Iron Man 3",
#     "Thor: The Dark World",
#     "Captain America: The Winter Soldier",
#     "Guardians of the Galaxy",
#     "Avengers: Age of Ultron",
#     "Ant-Man",
#     "Captain America: Civil War",
#     "Doctor Strange",
#     "Guardians of the Galaxy Vol. 2",
#     "Spider-Man: Homecoming",
#     "Thor: Ragnarok",
#     "Black Panther",
#     "Avengers: Infinity War",
#     "Ant-Man and the Wasp",
#     "Captain Marvel",
#     "Avengers: Endgame",
#     "Spider-Man: Far From Home",
#     "WandaVision",
#     "Loki",
#     "The Falcon and the Winter Soldier",
#     "Hawkeye",
#     "Moon Knight"
# ]

# Wizarding_World = [
#     "Wizarding World (Harry Potter)",
#     "Wizarding World",
#     "Harry Potter",
#     "Harry Potter and the Sorcerer's Stone",
#     "Harry Potter and the Philosopher's Stone",
#     "Harry Potter and the Chamber of Secrets",
#     "Harry Potter and the Prisoner of Azkaban",
#     "Harry Potter and the Goblet of Fire",
#     "Harry Potter and the Order of the Phoenix",
#     "Harry Potter and the Half-Blood Prince",
#     "Harry Potter and the Deathly Hallows: Part 1",
#     "Harry Potter and the Deathly Hallows: Part 2",
#     "Fantastic Beasts and Where to Find Them",
#     "Fantastic Beasts: The Crimes of Grindelwald",
#     "Fantastic Beasts: The Secrets of Dumbledore"
# ]

# Call_of_Duty = [
#     "Call of Duty",
#     "Call of Duty 2",
#     "Call of Duty 3",
#     "Call of Duty 4: Modern Warfare",
#     "Call of Duty: Modern Warfare 2",
#     "Call of Duty: Modern Warfare 3",
#     "Call of Duty: Modern Warfare (2019)",
#     "Call of Duty: Modern Warfare II",
#     "Call of Duty: Modern Warfare III",
#     "Call of Duty: World at War",
#     "Call of Duty: Black Ops",
#     "Call of Duty: Black Ops II",
#     "Call of Duty: Black Ops III",
#     "Call of Duty: Black Ops 4",
#     "Call of Duty: Black Ops Cold War",
#     "Call of Duty: Vanguard",
#     "Call of Duty: Ghosts",
#     "Call of Duty: Advanced Warfare",
#     "Call of Duty: Infinite Warfare",
#     "Call of Duty: Warzone"
# ]

# Batman = [
#     "Batman",
#     "Batman (1989)",
#     "Batman Returns",
#     "Batman Forever",
#     "Batman & Robin",
#     "Batman Begins",
#     "The Dark Knight",
#     "The Dark Knight Rises",
#     "Batman v Superman: Dawn of Justice",
#     "Justice League",
#     "Zack Snyder's Justice League",
#     "The Batman",
#     "The Lego Batman Movie",
#     "Batman: The Animated Series"
# ]

# Spider_Man = [
#     "Spider-Man",
#     "Spider Man",
#     "Spiderman",
#     "Spider-Man (2002)",
#     "Spider-Man 2",
#     "Spider-Man 3",
#     "The Amazing Spider-Man",
#     "The Amazing Spider-Man 2",
#     "Spider-Man: Homecoming",
#     "Spider-Man: Far From Home",
#     "Spider-Man: No Way Home",
#     "Spider-Man: Into the Spider-Verse",
#     "Spider-Man: Across the Spider-Verse",
#     "Spider-Man: The Animated Series"
# ]

# Cars = [
#     "Cars",
#     "Cars 2",
#     "Cars 3",
#     "Cars on the Road",
#     "Planes",
#     "Planes: Fire & Rescue"
# ]

# Candy_Crush = [
#     "Candy Crush",
#     "Candy Crush Saga",
#     "Candy Crush Soda Saga",
#     "Candy Crush Jelly Saga",
#     "Candy Crush Friends Saga"
# ]

# Looney_Tunes = [
#     "Looney Tunes",
#     "Merrie Melodies",
#     "The Looney Tunes Show",
#     "Looney Tunes Cartoons",
#     "Space Jam",
#     "Space Jam: A New Legacy"
# ]

# Teenage_Mutant_Ninja_Turtles = [
#     "Teenage Mutant Ninja Turtles",
#     "TMNT",
#     "Teenage Mutant Ninja Turtles (1990)",
#     "Teenage Mutant Ninja Turtles II: The Secret of the Ooze",
#     "Teenage Mutant Ninja Turtles III",
#     "TMNT (2007)",
#     "Teenage Mutant Ninja Turtles (2014)",
#     "Teenage Mutant Ninja Turtles: Out of the Shadows",
#     "Teenage Mutant Ninja Turtles: Mutant Mayhem",
#     "Rise of the Teenage Mutant Ninja Turtles",
#     "Rise of the Teenage Mutant Ninja Turtles: The Movie"
# ]

# SpongeBob_SquarePants = [
#     "SpongeBob SquarePants",
#     "Spongebob Squarepants",
#     "SpongeBob",
#     "The SpongeBob SquarePants Movie",
#     "The SpongeBob Movie: Sponge Out of Water",
#     "The SpongeBob Movie: Sponge on the Run",
#     "The Patrick Star Show",
#     "Kamp Koral: SpongeBob's Under Years"
# ]

# Lion_King = [
#     "The Lion King",
#     "Lion King",
#     "The Lion King II: Simba's Pride",
#     "The Lion King 1½",
#     "The Lion King (2019)",
#     "The Lion Guard"
# ]

# Dora_the_Explorer = [
#     "Dora the Explorer",
#     "Dora",
#     "Dora and Friends: Into the City!",
#     "Dora and the Lost City of Gold"
# ]

# Paw_Patrol = [
#     "Paw Patrol",
#     "PAW Patrol",
#     "PAW Patrol: The Movie",
#     "PAW Patrol: The Mighty Movie"
# ]

# Toy_Story = [
#     "Toy Story",
#     "Toy Story 2",
#     "Toy Story 3",
#     "Toy Story 4",
#     "Buzz Lightyear of Star Command",
#     "Lightyear"
# ]

# Peanuts = [
#     "Peanuts",
#     "Charlie Brown",
#     "Snoopy",
#     "A Charlie Brown Christmas",
#     "It's the Great Pumpkin, Charlie Brown",
#     "A Boy Named Charlie Brown",
#     "The Peanuts Movie",
#     "Snoopy Presents"
# ]

# Avengers = [
#     "Avengers",
#     "The Avengers",
#     "Avengers: Age of Ultron",
#     "Avengers: Infinity War",
#     "Avengers: Endgame",
#     "Avengers Assemble",
#     "Marvel's Avengers"
# ]

# Frozen = [
#     "Frozen",
#     "Frozen II",
#     "Olaf's Frozen Adventure",
#     "Once Upon a Snowman",
#     "Frozen Fever"
# ]

# Warcraft = [
#     "Warcraft",
#     "Warcraft: Orcs & Humans",
#     "Warcraft II: Tides of Darkness",
#     "Warcraft II: Beyond the Dark Portal",
#     "Warcraft III: Reign of Chaos",
#     "Warcraft III: The Frozen Throne",
#     "World of Warcraft",
#     "World of Warcraft: The Burning Crusade",
#     "World of Warcraft: Wrath of the Lich King",
#     "World of Warcraft: Cataclysm",
#     "World of Warcraft: Mists of Pandaria",
#     "World of Warcraft: Warlords of Draenor",
#     "World of Warcraft: Legion",
#     "World of Warcraft: Battle for Azeroth",
#     "World of Warcraft: Shadowlands",
#     "World of Warcraft: Dragonflight",
#     "Warcraft (2016)"
# ]

# Despicable_Me = [
#     "Despicable Me (Minions)",
#     "Despicable Me",
#     "Despicable Me 2",
#     "Despicable Me 3",
#     "Despicable Me 4",
#     "Minions",
#     "Minions: The Rise of Gru"
# ]

# Star_Trek = [
#     "Star Trek",
#     "Star Trek: The Original Series",
#     "Star Trek: The Next Generation",
#     "Star Trek: Deep Space Nine",
#     "Star Trek: Voyager",
#     "Star Trek: Enterprise",
#     "Star Trek: Discovery",
#     "Star Trek: Picard",
#     "Star Trek: Strange New Worlds",
#     "Star Trek (2009)",
#     "Star Trek Into Darkness",
#     "Star Trek Beyond"
# ]

# Jurassic_Park = [
#     "Jurassic Park",
#     "The Lost World: Jurassic Park",
#     "Jurassic Park III",
#     "Jurassic World",
#     "Jurassic World: Fallen Kingdom",
#     "Jurassic World Dominion",
#     "Camp Cretaceous"
# ]

# Grand_Theft_Auto = [
#     "Grand Theft Auto (GTA)",
#     "Grand Theft Auto",
#     "GTA",
#     "Grand Theft Auto III",
#     "Grand Theft Auto: Vice City",
#     "Grand Theft Auto: San Andreas",
#     "Grand Theft Auto IV",
#     "Grand Theft Auto V",
#     "GTA V",
#     "Grand Theft Auto: The Trilogy",
#     "GTA: The Trilogy"
# ]

# James_Bond = [
#     "James Bond",
#     "007",
#     "Dr. No",
#     "From Russia with Love",
#     "Goldfinger",
#     "Thunderball",
#     "You Only Live Twice",
#     "On Her Majesty's Secret Service",
#     "Live and Let Die",
#     "The Spy Who Loved Me",
#     "Moonraker",
#     "GoldenEye",
#     "Tomorrow Never Dies",
#     "The World Is Not Enough",
#     "Die Another Day",
#     "Casino Royale",
#     "Quantum of Solace",
#     "Skyfall",
#     "Spectre",
#     "No Time to Die"
# ]

# Angry_Birds = [
#     "Angry Birds",
#     "The Angry Birds Movie",
#     "The Angry Birds Movie 2",
#     "Angry Birds Toons"
# ]

# ############################

# Pokemon = [
#     "Pokémon",
#     "Pokemon",
#     "Pokémon: The First Movie",
#     "Pokémon the Movie 2000",
#     "Pokémon: Detective Pikachu",
#     "Pokémon Journeys",
#     "Pokémon Indigo League",
#     "Pokémon XYZ",
#     "Pokémon Sun & Moon",
#     "Pokémon Scarlet & Violet"
# ]

# Anpanman = [
#     "Anpanman",
#     "Soreike! Anpanman",
#     "Anpanman the Movie"
# ]

# Hello_Kitty = [
#     "Hello Kitty",
#     "Hello Kitty and Friends",
#     "Hello Kitty's Furry Tale Theater",
#     "Hello Kitty Paradise",
#     "Hello Kitty Island Adventure"
# ]

# Pac_Man = [
#     "Pac-Man",
#     "Pac Man",
#     "PAC-MAN",
#     "Pac-Man and the Ghostly Adventures"
# ]

# Space_Invaders = [
#     "Space Invaders",
#     "Space Invaders: Invasion Day"
# ]

# Dragon_Ball = [
#     "Dragon Ball",
#     "Dragon Ball Z",
#     "Dragon Ball GT",
#     "Dragon Ball Super",
#     "Dragon Ball Z: Battle of Gods",
#     "Dragon Ball Super: Broly",
#     "Dragon Ball Super: Super Hero"
# ]

# Street_Fighter = [
#     "Street Fighter",
#     "Street Fighter II",
#     "Street Fighter Alpha",
#     "Street Fighter IV",
#     "Street Fighter V",
#     "Street Fighter: The Movie"
# ]

# Rilakkuma = [
#     "Rilakkuma",
#     "Rilakkuma and Kaoru",
#     "Rilakkuma's Theme Park Adventure"
# ]

# Monster_Strike = [
#     "Monster Strike",
#     "Monster Strike The Animation",
#     "Monster Strike the Movie"
# ]

# Demon_Slayer = [
#     "Demon Slayer: Kimetsu no Yaiba",
#     "Demon Slayer",
#     "Demon Slayer: Mugen Train",
#     "Demon Slayer: Entertainment District Arc",
#     "Demon Slayer: Swordsmith Village Arc"
# ]

# Mario = [
#     "Mario",
#     "Super Mario Bros.",
#     "Super Mario Bros. Movie",
#     "The Super Mario Bros. Movie",
#     "Mario Kart",
#     "Super Mario World"
# ]

# Super_Sentai_Power_Rangers = [
#     "Super Sentai / Power Rangers",
#     "Super Sentai",
#     "Power Rangers",
#     "Mighty Morphin Power Rangers",
#     "Power Rangers Dino Fury",
#     "Power Rangers Cosmic Fury"
# ]

# Ultraman = [
#     "Ultra Series (Ultraman)",
#     "Ultraman",
#     "Ultra Series",
#     "Ultraman Tiga",
#     "Ultraman Zero",
#     "Shin Ultraman"
# ]

# Sonic_the_Hedgehog = [
#     "Sonic the Hedgehog",
#     "Sonic",
#     "Sonic the Hedgehog (2020)",
#     "Sonic the Hedgehog 2",
#     "Sonic Prime"
# ]

# Fate = [
#     "Fate (Fate/stay night)",
#     "Fate",
#     "Fate/stay night",
#     "Fate/Zero",
#     "Fate/stay night: Unlimited Blade Works",
#     "Fate/Grand Order"
# ]

# Yu_Gi_Oh = [
#     "Yu-Gi-Oh!",
#     "Yu Gi Oh",
#     "Yu-Gi-Oh! Duel Monsters",
#     "Yu-Gi-Oh! GX",
#     "Yu-Gi-Oh! The Dark Side of Dimensions"
# ]

# Gundam = [
#     "Gundam",
#     "Mobile Suit Gundam",
#     "Gundam Wing",
#     "Gundam SEED",
#     "Gundam 00",
#     "Gundam Unicorn",
#     "Mobile Suit Gundam: The Witch from Mercury"
# ]

# Beyblade = [
#     "Beyblade",
#     "Beyblade Burst",
#     "Beyblade Metal Fusion",
#     "Beyblade X"
# ]

# Gran_Turismo = [
#     "Gran Turismo",
#     "Gran Turismo (2023)"
# ]

# Hamtaro = [
#     "Hamtaro",
#     "Tottoko Hamtaro"
# ]

# Astro_Boy = [
#     "Astro Boy",
#     "Astroboy",
#     "Astro Boy (2009)"
# ]

# Godzilla = [
#     "Godzilla (Gojira)",
#     "Godzilla",
#     "Gojira",
#     "Godzilla (1954)",
#     "Godzilla (2014)",
#     "Shin Godzilla",
#     "Godzilla vs. Kong",
#     "Godzilla Minus One"
# ]

# Sailor_Moon = [
#     "Sailor Moon",
#     "Pretty Guardian Sailor Moon",
#     "Sailor Moon Crystal",
#     "Sailor Moon Eternal",
#     "Sailor Moon Cosmos"
# ]

# Kumamon = [
#     "Kumamon",
#     "Kumamoto Mascot Kumamon"
# ]

# Yo_kai_Watch = [
#     "Yo-kai Watch",
#     "Yokai Watch",
#     "Yo-kai Watch: The Movie",
#     "Yo-kai Watch Shadowside"
# ]

# Resident_Evil = [
#     "Resident Evil (Biohazard)",
#     "Resident Evil",
#     "Biohazard",
#     "Resident Evil (2002)",
#     "Resident Evil: Apocalypse",
#     "Resident Evil: Extinction",
#     "Resident Evil: Afterlife",
#     "Resident Evil: Retribution",
#     "Resident Evil: The Final Chapter",
#     "Resident Evil: Welcome to Raccoon City"
# ]

# Neon_Genesis_Evangelion = [
#     "Neon Genesis Evangelion",
#     "Evangelion",
#     "The End of Evangelion",
#     "Rebuild of Evangelion",
#     "Evangelion: 1.0 You Are (Not) Alone",
#     "Evangelion: 2.0 You Can (Not) Advance",
#     "Evangelion: 3.0 You Can (Not) Redo",
#     "Evangelion: 3.0+1.0 Thrice Upon a Time"
# ]


# US_IPs = [
#     Star_Wars,
#     Disney_Princess,
#     Barbie,
#     Marvel_Cinematic_Universe,
#     Wizarding_World,
#     Call_of_Duty,
#     Batman,
#     Spider_Man,
#     Cars,
#     Candy_Crush,
#     Looney_Tunes,
#     Teenage_Mutant_Ninja_Turtles,
#     SpongeBob_SquarePants,
#     Lion_King,
#     Dora_the_Explorer,
#     Paw_Patrol,
#     Toy_Story,
#     Peanuts,
#     Avengers,
#     Frozen,
#     Warcraft,
#     Despicable_Me,
#     Star_Trek,
#     Jurassic_Park,
#     Grand_Theft_Auto,
#     James_Bond,
#     Angry_Birds
# ]

# JP_IPs = [
#     Pokemon,
#     Anpanman,
#     Hello_Kitty,
#     Pac_Man,
#     Space_Invaders,
#     Dragon_Ball,
#     Street_Fighter,
#     Rilakkuma,
#     Monster_Strike,
#     Demon_Slayer,
#     Mario,
#     Super_Sentai_Power_Rangers,
#     Ultraman,
#     Sonic_the_Hedgehog,
#     Fate,
#     Yu_Gi_Oh,
#     Gundam,
#     Beyblade,
#     Gran_Turismo,
#     Hamtaro,
#     Astro_Boy,
#     Godzilla,
#     Sailor_Moon,
#     Kumamon,
#     Yo_kai_Watch,
#     Resident_Evil,
#     Neon_Genesis_Evangelion
# ]

# US_unique_providers = dict()
# JP_unique_providers = dict()

# def get_unique_providers(IPs: list[list[str]], unique_dict: dict):
#     for IP_List in IPs:
#         franchise_name = IP_List[0]
#         if franchise_name == "Snow White":
#             franchise_name = "Disney_Princess"

#         final_set = set()

#         for IP in IP_List:
#             tv_search = tmdb.Search()
#             tv_search.tv(query=IP)
#             tv_results = tv_search.results or []

#             for show in tv_results:
#                 print(f"Now doing TV: {show.get('name')}")
#                 show_id = show.get("id")
#                 print(show_id)
#                 if not show_id:
#                     continue

#                 try:
#                     providers = tmdb.TV(show_id).watch_providers()
#                 except Exception:
#                     continue

#                 if not providers or "results" not in providers:
#                     continue

#                 for data in providers["results"].values():
#                     for bucket in ["flatrate", "free", "ads", "rent", "buy"]:
#                         for p in data.get(bucket, []) or []:
#                             final_set.add(p["provider_name"])

#             movie_search = tmdb.Search()
#             movie_search.movie(query=IP)
#             movie_results = movie_search.results or []
            
#             for movie in movie_results:
#                 print(f"Now doing Movie: {movie.get('title')}")
#                 movie_id = movie.get("id")
#                 if not movie_id:
#                     print("NONE MOVIE")
#                     continue

#                 try:
#                     providers = tmdb.Movies(movie_id).watch_providers()
#                 except Exception:
#                     continue

#                 if not providers or "results" not in providers:
#                     continue

#                 for data in providers["results"].values():
#                     for bucket in ["flatrate", "free", "ads", "rent", "buy"]:
#                         for p in data.get(bucket, []) or []:
#                             final_set.add(p["provider_name"])

#         unique_dict[franchise_name] = final_set

# data = dict()

# for IP in US_unique_providers:
#     data[IP] = int(len(US_unique_providers[IP]))

# for IP in JP_unique_providers:
#     if len(JP_unique_providers[IP]) == 0:
#         data[IP] = None 
#     else:
#         data[IP] = int(len(JP_unique_providers[IP]))

# df = pd.DataFrame(
#     [{"Franchise": ip, "Number of Platforms": n} for ip, n in data.items()]
# )

# df.to_csv("ip_accessibility.csv", index=False)

# %%
#loading the data
path = '~/Group060_WI26/data/ip_accessibility.csv'
providers_df = pd.read_csv(path)
providers_df["Number of Platforms"] = providers_df["Number of Platforms"].astype("Int64")
providers_df = providers_df.dropna()
print(providers_df.describe())

plt.figure(figsize=(12, 5))
sns.barplot(
    data=providers_df.sort_values("Number of Platforms", ascending=False),
    x="Franchise",
    y="Number of Platforms"
)



plt.xticks(rotation=45, ha="right")
plt.title("Streaming Accessibility by IP")
plt.xlabel("IP")
plt.ylabel("Number of Streaming Platforms")
plt.tight_layout()
plt.show()
# Out:
#        Number of Platforms
# count                 52.0
# mean             69.038462
# std              50.377384
# min                    0.0
# 25%                  31.75
# 50%                   62.0
# 75%                 102.25
# max                  247.0

# %% [markdown]
# ### Merged DataFrame

# %% [markdown]
# We combined all our dataframes into one dataframe. In the dataframe below, we can access one IP per row and each column provides a different metric (revenue, creation date, streaming accessibility, etc.) with the exception of search interest, as that makes the dataframe hard to read. Leaving out search interest makes it easier for the parts in our data analysis that do not use search interest data.
#
# However, in the section following this one, we will include search interest in our dataframe and create a full dataframe with all metrics used in our study. This will be useful for the part in our analysis that uses search interest data.

# %%
top_table_japan['Country']='Japan'
top27_table_us['Country']='US'

#Add Countries Column
addcountry_table = pd.concat([top_table_japan, top27_table_us], ignore_index=True)

#Add Streaming Accessibility
merged_table = pd.merge(
    addcountry_table,
    providers_df[['Franchise', 'Number of Platforms']],
    on='Franchise',
    how='left' 
)

merged_table.to_csv("data/02-processed/merged_table.csv", index=False)

merged_table
# Out:
#                           Franchise  Creation Date  Revenue (Billion USD)  \
# 0                          Anpanman           1973                  38.40
# 1                       Hello Kitty           1974                  33.50
# 2                           Pac-Man           1980                  15.43
# 3                    Space Invaders           1978                  13.90
# 4                       Dragon Ball           1984                  10.70
# 5                    Street Fighter           1987                  10.70
# 6                         Rilakkuma           2003                  10.00
# 7                    Monster Strike           2013                  10.00
# 8    Demon Slayer: Kimetsu no Yaiba           2016                  10.00
# 9                             Mario           1981                   8.75
# 10     Super Sentai / Power Rangers           1975                   8.67
# 11          Ultra Series (Ultraman)           1966                   7.40
# ...

# %% [markdown]
# ### Full DataFrame with Search Interest

# %% [markdown]
# The dataframe below builds on the merged dataframe above, but includes each IP's monthly search interests from Google Trends. In the dataframe, each row contains the month (dating from 2004 to present), the actual search interest of the IP in that month, IP name, and all the other metrics that were included in the previous dataframe.

# %%
df_cleaned['Franchise'] = df_cleaned['Franchise'].str.strip().str.title()
merged_table['Franchise'] = merged_table['Franchise'].str.strip().str.title()

name_corrections = {
    "Pokemon": "Pokémon",
    "Mario": "Super Mario",
    "Super Sentai / Power Rangers": "Power Rangers",
    "Ultra Series (Ultraman)": "Ultraman",
    "Fate/stay Night": "Fate (Fate/stay night)",
    "Godzilla": "Godzilla (Gojira)",
    "Resident Evil": "Resident Evil (Biohazard)",
    "Harry Potter": "Wizarding World (Harry Potter)",
    "MCU": "Marvel Cinematic Universe (MCU)",
    "Marvel Entertainment": "Marvel Cinematic Universe (MCU)",
    "The Avengers": "Avengers",
    "Grand Theft Auto": "Grand Theft Auto (GTA)",
    "Yo-Kai Watch": "Yo-kai Watch",
    "Paw Patrol": "Paw Patrol",
    "Candy Crush Saga": "Candy Crush",
    "Despicable Me": "Despicable Me (Minions)",
    "Bruce Wayne": "Batman",
    "World Of Warcraft": "Warcraft"
    # add any other known mismatches here
}
df_cleaned['Franchise'] = df_cleaned['Franchise'].replace(name_corrections)
merged_table['Franchise'] = merged_table['Franchise'].replace(name_corrections)

full_table = pd.merge(
    df_cleaned,
    merged_table,
    on='Franchise',
    how='left'
)

full_table['Revenue (Billion USD)'] = full_table['Revenue (Billion USD)'].astype(str)
full_table['Revenue (Billion USD)'] = (
    full_table['Revenue (Billion USD)']
    .replace(r'[\$,]', '', regex=True)
    .str.replace('\xa0', '')  # remove non-breaking spaces
    .str.strip()
)
full_table['Revenue (Billion USD)'] = pd.to_numeric(full_table['Revenue (Billion USD)'], errors='coerce')


full_table = full_table[
    ['Franchise', 'Country', 'Creation Date', 'Revenue (Billion USD)', 'Number of Platforms', 'Month', 'Interest Value']
]

full_table.to_csv("data/02-processed/full_table.csv", index=False)

full_table
# Out:
#           Franchise Country  Creation Date  Revenue (Billion USD)  \
# 0       Angry Birds      US           2009                   9.54
# 1          Anpanman   Japan           1973                  38.40
# 2         Astro Boy   Japan           1952                   3.00
# 3            Barbie      US           1987                  36.30
# 4          Beyblade   Japan           1999                   4.60
# ...             ...     ...            ...                    ...
# 14093     Toy Story      US           1995                  14.80
# 14094      Ultraman   Japan           1966                   7.40
# 14095      Warcraft      US           1994                  12.40
# 14096  Yo-kai Watch   Japan           2013                   2.09
# 14097     Yu-Gi-Oh!   Japan           1996                   5.42
#
#        Number of Platforms      Month  Interest Value
# 0                       76 2004-01-01               0
# 1                       13 2004-01-01               0
# ...

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis

# %% [markdown]
# We will first reload our fully wrangled dataset from data/02-processed

# %%
full_table = pd.read_csv("data/02-processed/full_table.csv")
merged_table = pd.read_csv("data/02-processed/merged_table.csv")

# %% [markdown]
# #### Correlation Relationship with IPs (regardless of country)
# Below, we will examine the correlation relationship when taking all IPs in our dataset into consideration, which will provide insight about which variable has the strongest positive correlation with cumulative global revenue for IPs in general. We will produce three scatterplots, each exploring the relationship between a different pair of variables. We will apply both the Pearson and Spearman's correlation for each scatterplot to examine the relationship between each pair of variables.
#
# 1. Average Search Interest (x-variable) vs Cumulative Global Revenue (y-variable)
# 2. Media Exposure (x-variable) vs Cumulative Global Revenue (y-variable)
# 3. Creation Date (x-variable) vs Cumulative Global Revenue (y-variable)

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

#Average Search Interest vs Global Revenue
avg_df = (
    full_table
    .groupby('Franchise', as_index=False)
    .agg({
        'Interest Value': 'median',
        'Revenue (Billion USD)': 'first'
    })
)

plt.figure(figsize=(10,6))
plt.scatter(
    avg_df['Interest Value'],
    avg_df['Revenue (Billion USD)'],
    alpha=0.7
)
plt.xlabel('Average Search Interest')
plt.ylabel('Cumulative Global Revenue (Billion USD)')
plt.title('Average Search Interest vs Cumulative Global Revenue per IP')
plt.grid(True)
plt.savefig("results/search_vs_revenue_all.png", dpi=300, bbox_inches="tight")
plt.show()


pearson_r, pearson_p = pearsonr(
    avg_df['Interest Value'],
    avg_df['Revenue (Billion USD)']
)

spearman_r, spearman_p = spearmanr(
    avg_df['Interest Value'],
    avg_df['Revenue (Billion USD)']
)

print(f"Pearson r = {pearson_r:.4f}, p-value = {pearson_p:.4f}")
print(f"Spearman ρ = {spearman_r:.4f}, p-value = {spearman_p:.4f}")
# Out:
# Pearson r = 0.2429, p-value = 0.0797
# Spearman ρ = 0.2824, p-value = 0.0404

# %% [markdown]
# There is a weak, positive linear relationship between average search interest and cumulative global revenue of IPs, as the r value for the Pearson's correlation is 0.2429. This means that IPs with higher average search interest tends to have a higher cumulative global revenue. The p-value (0.0797) corresponding to r is greater than 0.05, so the result is not statistically significant. This means that there is not enough evidence that a higher average search interest explains the trend for a higher cumulative global revenue.
#
# Spearman's correlation shows a weak, positive monotonic relationship between average search interest and cumulative global revenue of IPs, as the correlation coefficient ρ is 0.2824. This means that IPs with higher average search interest tend to have a higher cumulative global revenue; because ρ is greater than r, this means that the relationship is closer to being non-linear. The p-value (0.0404) corresponding to ρ is very small, which means that the result is statistically significant. This means that there is evidence that a higher average search interest explains the non-linear trend for a higher cumulative global revenue.

# %%
#Media Exposure vs Global Revenue
ip_media_df = merged_table[['Number of Platforms', 'Revenue (Billion USD)']]
ip_media_df = ip_media_df.dropna()

plt.figure(figsize=(10,6))
plt.scatter(
    ip_media_df['Number of Platforms'],
    ip_media_df['Revenue (Billion USD)'],
    alpha=0.7
)

plt.xlabel('Media Exposure (Number of Streaming Platforms)')
plt.ylabel('Cumulative Global Revenue (Billion USD)')
plt.title('Media Exposure vs Cumulative Global Revenue per IP')
plt.grid(True)
plt.savefig("results/media_vs_revenue_all.png", dpi=300, bbox_inches="tight")
plt.show()

pearson_r, pearson_p = pearsonr(
    ip_media_df['Number of Platforms'],
    ip_media_df['Revenue (Billion USD)']
)

spearman_r, spearman_p = spearmanr(
    ip_media_df['Number of Platforms'],
    ip_media_df['Revenue (Billion USD)']
)

print(f"Pearson r = {pearson_r:.4f}, p-value = {pearson_p:.4f}")
print(f"Spearman ρ = {spearman_r:.4f}, p-value = {spearman_p:.4f}")
# Out:
# Pearson r = 0.3349, p-value = 0.0163
# Spearman ρ = 0.2356, p-value = 0.0961

# %% [markdown]
# There is a moderate, positive linear relationship between media exposure and cumulative global revenue of IPs, as the r value for the Pearson's correlation is 0.3349. This means that IPs with more media exposure tend to have a higher cumulative global revenue. The p-value (0.0163) corresponding to r is very small, so the result is statistically significant. This means that there is enough evidence that media exposure explains the trend for higher cumulative global revenues.
#
# Spearman's correlation shows a weak, positive monotonic relationship between media exposure and cumulative global revenue of IPs, as the correlation coefficient ρ is 0.2356. This means that IPs with more media exposure tends to have a higher cumulative global revenue; because r is greater than ρ, the relationship is closer to being linear. The p-value (0.0961) corresponding to ρ is large, which means that the result is not statistically significant. This means that there is not enough evidence that media exposure explains the non-linear trend for a higher cumulative global revenue.

# %%
#Creation Date vs Global Revenue
creation_df = merged_table

plt.figure(figsize=(10,6))
plt.scatter(
    creation_df['Creation Date'],
    creation_df['Revenue (Billion USD)'],
    alpha=0.7
)

plt.xlabel('Creation Date')
plt.ylabel('Cumulative Global Revenue (Billion USD)')
plt.title('Creation Date vs Cumulative Global Revenue per IP')
plt.grid(True)
plt.savefig("results/creation_vs_revenue_all.png", dpi=300, bbox_inches="tight")
plt.show()

pearson_r, pearson_p = pearsonr(
    creation_df['Creation Date'],
    creation_df['Revenue (Billion USD)']
)

spearman_r, spearman_p = spearmanr(
    creation_df['Creation Date'],
    creation_df['Revenue (Billion USD)']
)

print(f"Pearson r = {pearson_r:.4f}, p-value = {pearson_p:.4f}")
print(f"Spearman ρ = {spearman_r:.4f}, p-value = {spearman_p:.4f}")
# Out:
# Pearson r = -0.0899, p-value = 0.5221
# Spearman ρ = -0.0886, p-value = 0.5283

# %% [markdown]
# There is a very weak, negative linear relationship between creation date and cumulative global revenue of IPs, as the r value for the Pearson's correlation is -0.0899. This means that IPs with older creation dates tend to have a lower cumulative global revenue. The p-value (0.5221) corresponding to r is very large, so the result is not statistically significant. This means that there is not enough evidence that older creation dates explain the trend for lower cumulative global revenues.
#
# Spearman's correlation shows a very weak, negative monotonic relationship between creation date and cumulative global revenue of IPs, as the correlation coefficient ρ is -0.0886. The p-value (0.5283) corresponding to ρ is large, so the result is not statistically significant. This means that there is not enough evidence that older creation dates explains the trend for lower cumulative global revenues.

# %% [markdown]
# #### Correlation Relationship with Japanese IPs
# Below, we will examine the correlation relationship when looking at only Japanese IPs in our dataset, and look at which variable has the strongest positive correlation with cumulative global revenue for Japanese IPs. We will produce three scatterplots, each exploring the relationship between a different pair of variables. We will also apply both the Pearson and Spearman's correlation for each scatterplot to examine the relationship between each pair of variables.
#
# 1. Average Search Interest (x-variable) vs Cumulative Global Revenue (y-variable)
# 2. Media Exposure (x-variable) vs Cumulative Global Revenue (y-variable)
# 3. Creation Date (x-variable) vs Cumulative Global Revenue (y-variable)

# %%
#Average Search Interest vs Global Revenue

jp_df = full_table[full_table['Country']=='Japan']


jp_avg = (
    jp_df
    .groupby('Franchise', as_index=False)
    .agg({
        'Interest Value': 'median',
        'Revenue (Billion USD)': 'first'
    })
)

plt.figure(figsize=(10,6))
plt.scatter(
    jp_avg['Interest Value'],
    jp_avg['Revenue (Billion USD)'],
    alpha=0.7
)
plt.xlabel('Average Search Interest')
plt.ylabel('Cumulative Global Revenue (Billion USD)')
plt.title('Average Search Interest vs Cumulative Global Revenue per Japanese IP')
plt.grid(True)
plt.savefig("results/search_vs_revenue_jp.png", dpi=300, bbox_inches="tight")
plt.show()

pearson_r, pearson_p = pearsonr(
    jp_avg['Interest Value'],
    jp_avg['Revenue (Billion USD)']
)

spearman_r, spearman_p = spearmanr(
    jp_avg['Interest Value'],
    jp_avg['Revenue (Billion USD)']
)

print(f"Pearson r = {pearson_r:.4f}, p-value = {pearson_p:.4f}")
print(f"Spearman ρ = {spearman_r:.4f}, p-value = {spearman_p:.4f}")
# Out:
# Pearson r = 0.1313, p-value = 0.5226
# Spearman ρ = 0.3410, p-value = 0.0882

# %% [markdown]
# There is a weak, positive linear relationship between average search interest and cumulative global revenue of Japanese IPs, as the r value for the Pearson's correlation is 0.1313. This means that Japanese IPs with higher average search interest tend to have a higher cumulative global revenue. The p-value (0.5226) corresponding to r is large, so the result is not statistically significant. This means that there is not enough evidence that a higher average search interest explains the trend for a higher cumulative global revenue for Japanese IPs.
#
# Spearman's correlation shows a moderate, positive monotonic relationship between average search interest and cumulative global revenue of Japanese IPs, as the correlation coefficient ρ is 0.3410. This means that Japanese IPs with higher average search interest tend to have higher cumulative global revenues; because ρ is greater than r, this suggests that the relationship is closer to being non-linear. The p-value (0.0882) corresponding to ρ is greater than 0.05, which means that the result is not statistically significant. This means that there is not enough evidence that average search interest explains the trend for higher cumulative global revenues for Japanese IPs.

# %%
#Media Exposure (x-variable) vs Global Revenue (y-variable)

jp_exp_df = merged_table[merged_table['Country']=='Japan']
jp_exp_df = jp_exp_df.dropna()
plt.figure(figsize=(10,6))
plt.scatter(
    jp_exp_df['Number of Platforms'],
    jp_exp_df['Revenue (Billion USD)'],
    alpha=0.7
)

plt.xlabel('Media Exposure (Number of Streaming Platforms)')
plt.ylabel('Cumulative Global Revenue (Billion USD)')
plt.title('Media Exposure vs Cumulative Global Revenue per Japanese IP')
plt.grid(True)
plt.savefig("results/media_vs_revenue_jp.png", dpi=300, bbox_inches="tight")
plt.show()

pearson_r, pearson_p = pearsonr(
    jp_exp_df['Number of Platforms'],
    jp_exp_df['Revenue (Billion USD)']
)

spearman_r, spearman_p = spearmanr(
    jp_exp_df['Number of Platforms'],
    jp_exp_df['Revenue (Billion USD)']
)

print(f"Pearson r = {pearson_r:.4f}, p-value = {pearson_p:.4f}")
print(f"Spearman ρ = {spearman_r:.4f}, p-value = {spearman_p:.4f}")
# Out:
# Pearson r = -0.2504, p-value = 0.2380
# Spearman ρ = -0.0403, p-value = 0.8519

# %% [markdown]
# There is a weak, negative linear relationship between media exposure and cumulative global revenue of Japanese IPs, as the r value for the Pearson's correlation is -0.2504. This means that Japanese IPs with more media exposure tends to have lower cumulative global revenues. The p-value (0.2380) corresponding to r is large, so the result is not statistically significant. This means that there is not enough evidence that a higher media exposure explains the trend for a lower cumulative global revenue for Japanese IPs.
#
# Spearman's correlation shows a very weak, negative monotonic relationship between media exposure and cumulative global revenue of Japanese IPs, as the correlation coefficient ρ is -0.0403. This means that Japanese IPs with more media exposure tends to have a lower cumulative global revenue; because r has a greater absolute value than ρ, this suggests that the relationship is closer to being linear. The p-value (0.8519) corresponding to ρ is very large, which means that the result is not statistically significant. This means that there is not enough evidence that media exposure explains the trend for a lower cumulative global revenue for Japanese IPs.

# %%
# Creation Date vs Global Revenue for JAPANESE IPs
japan_creation = merged_table[merged_table['Country']=='Japan']

# Plot
plt.figure(figsize=(10,6))
plt.scatter(
    japan_creation['Creation Date'],
    japan_creation['Revenue (Billion USD)'],
    alpha=0.7
)

plt.xlabel('Creation Date')
plt.ylabel('Cumulative Global Revenue (Billion USD)')
plt.title('Creation Date vs Cumulative Global Revenue per Japanese IP')
plt.grid(True)
plt.savefig("results/creation_vs_revenue_jp.png", dpi=300, bbox_inches="tight")
plt.show()

pearson_r, pearson_p = pearsonr(
    japan_creation['Creation Date'],
    japan_creation['Revenue (Billion USD)']
)

spearman_r, spearman_p = spearmanr(
    japan_creation['Creation Date'],
    japan_creation['Revenue (Billion USD)']
)

print(f"Pearson r = {pearson_r:.4f}, p-value = {pearson_p:.4f}")
print(f"Spearman ρ = {spearman_r:.4f}, p-value = {spearman_p:.4f}")
# Out:
# Pearson r = -0.2540, p-value = 0.2105
# Spearman ρ = -0.2697, p-value = 0.1827

# %% [markdown]
# There is a weak, negative linear relationship between creation date and cumulative global revenue of Japanese IPs, as the r value for the Pearson's correlation is -0.2540. This means that Japanese IPs with older creation dates tends to have lower cumulative global revenues. The p-value (0.2105) corresponding to r is very large, so the result is not statistically significant. This means that there is not enough evidence that an older creation date explains the trend for a lower cumulative global revenue for Japanese IPs.
#
# Spearman's correlation shows a weak, negative monotonic relationship between creation date and cumulative global revenue of Japanese IPs, as the correlation coefficient ρ is -0.2697. This means that Japanese IPs with an older creation date tends to have a lower cumulative global revenue. The p-value (0.1827) corresponding to ρ is large, which means that the result is not statistically significant. This means that there is not enough evidence that the an older creation date explains the trend for a lower cumulative global revenue for Japanese IPs.

# %% [markdown]
# #### Correlation Relationship with US IPs
# Below, we will examine the correlation relationship when only looking at US IPs in our dataset, and look at which variable has the strongest positive correlation with cumulative global revenue for US IPs. We will produce three scatterplots, each exploring the relationship between a different pair of variables. We will also apply both the Pearson and Spearman's correlation for each scatterplot to examine the relationship between each pair of variables.
#
# 1. Average Search Interest (x-variable) vs Cumulative Global Revenue (y-variable)
# 2. Media Exposure (x-variable) vs Cumulative Global Revenue (y-variable)
# 3. Creation Date (x-variable) vs Cumulative Global Revenue (y-variable)

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

#Average Search Interest vs Global Revenue  
us_df = full_table[full_table['Country']=='US']

us_avg = (
    us_df
    .groupby('Franchise', as_index=False)
    .agg({
        'Interest Value': 'median',
        'Revenue (Billion USD)': 'first'
    })
)

plt.figure(figsize=(10,6))
plt.scatter(
    us_avg['Interest Value'],
    us_avg['Revenue (Billion USD)'],
    alpha=0.7
)
plt.xlabel('Average Search Interest')
plt.ylabel('Cumulative Global Revenue (Billion USD)')
plt.title('Average Search Interest vs Cumulative Global Revenue per US IP')
plt.grid(True)
plt.savefig("results/search_vs_revenue_us.png", dpi=300, bbox_inches="tight")
plt.show()

pearson_r, pearson_p = pearsonr(
    us_avg['Interest Value'],
    us_avg['Revenue (Billion USD)']
)

spearman_r, spearman_p = spearmanr(
    us_avg['Interest Value'],
    us_avg['Revenue (Billion USD)']
)

print(f"Pearson r = {pearson_r:.4f}, p-value = {pearson_p:.4f}")
print(f"Spearman ρ = {spearman_r:.4f}, p-value = {spearman_p:.4f}")
# Out:
# Pearson r = 0.1617, p-value = 0.4203
# Spearman ρ = 0.2368, p-value = 0.2343

# %% [markdown]
# There is a weak, positive linear relationship between average search interest and cumulative global revenue of US IPs, as the r value for the Pearson's correlation is 0.1617. This means that US IPs with higher average search interests tend to have a higher cumulative global revenue. The p-value (0.4203) corresponding to r is very large, so the result is not statistically significant. This means that there is not enough evidence that higher average search interests explains the trend for higher cumulative global revenues for US IPs.
#
# Spearman's correlation shows a weak, positive monotonic relationship between average search interest and cumulative global revenue of US IPs, as the correlation coefficient ρ is 0.2368. This means that US IPs with a higher average search interest tends to have a higher cumulative global revenue. The p-value (0.2343) corresponding to ρ is large, which means that the result is not statistically significant. This means that there is not enough evidence that higher average search interests explain the trend for higher cumulative global revenues for US IPs.

# %%
#Media Exposure (x-variable) vs Global Revenue (y-variable)

us_exp_df = merged_table[merged_table['Country']=='US']
us_exp_df = us_exp_df.dropna()
plt.figure(figsize=(10,6))
plt.scatter(
    us_exp_df['Number of Platforms'],
    us_exp_df['Revenue (Billion USD)'],
    alpha=0.7
)

plt.xlabel('Media Exposure (Number of Streaming Platforms)')
plt.ylabel('Cumulative Global Revenue (Billion USD)')
plt.title('Media Exposure vs Cumulative Global Revenue per US IP')
plt.grid(True)
plt.savefig("results/media_vs_revenue_us.png", dpi=300, bbox_inches="tight")
plt.show()

pearson_r, pearson_p = pearsonr(
    us_exp_df['Number of Platforms'],
    us_exp_df['Revenue (Billion USD)']
)

spearman_r, spearman_p = spearmanr(
    us_exp_df['Number of Platforms'],
    us_exp_df['Revenue (Billion USD)']
)

print(f"Pearson r = {pearson_r:.4f}, p-value = {pearson_p:.4f}")
print(f"Spearman ρ = {spearman_r:.4f}, p-value = {spearman_p:.4f}")
# Out:
# Pearson r = 0.3599, p-value = 0.0652
# Spearman ρ = 0.0776, p-value = 0.7006

# %% [markdown]
# There is a moderate, positive linear relationship between media exposure and cumulative global revenue of US IPs, as the r value for the Pearson's correlation is 0.3599. This means that US IPs with higher media exposure tend to have higher cumulative global revenues. The p-value (0.0652) corresponding to r is small, so the result is statistically significant. This means that there is enough evidence that a higher media exposure explains the trend for a higher cumulative global revenue for US IPs.
#
# Spearman's correlation shows a very weak, positive monotonic relationship between media exposure and cumulative global revenue of US IPs, as the correlation coefficient ρ is 0.0776. This means that US IPs with higher media exposure tend to have higher cumulative global revenues. The p-value (0.7006) corresponding to ρ is large, which means that the result is not statistically significant. This means that there is not enough evidence that higher media exposures explain the trend for higher cumulative global revenues for US IPs.

# %%
#Creation Date vs Global Revenue
us_creation = merged_table[merged_table['Country']=='US']

# Plot
plt.figure(figsize=(10,6))
plt.scatter(
    us_creation['Creation Date'],
    us_creation['Revenue (Billion USD)'],
    alpha=0.7
)

plt.xlabel('Creation Date')
plt.ylabel('Cumulative Global Revenue (Billion USD)')
plt.title('Creation Date vs Cumulative Global Revenue per US IP')
plt.grid(True)
plt.savefig("results/creation_vs_revenue_us.png", dpi=300, bbox_inches="tight")
plt.show()

pearson_r, pearson_p = pearsonr(
    us_creation['Creation Date'],
    us_creation['Revenue (Billion USD)']
)

spearman_r, spearman_p = spearmanr(
    us_creation['Creation Date'],
    us_creation['Revenue (Billion USD)']
)

print(f"Pearson r = {pearson_r:.4f}, p-value = {pearson_p:.4f}")
print(f"Spearman ρ = {spearman_r:.4f}, p-value = {spearman_p:.4f}")
# Out:
# Pearson r = 0.0122, p-value = 0.9517
# Spearman ρ = -0.0257, p-value = 0.8989

# %% [markdown]
# There is a very weak, positive linear relationship between creation date and cumulative global revenue of US IPs, as the r value for the Pearson's correlation is 0.0122. This means that US IPs with older creation dates tend to have higher cumulative global revenues. The p-value (0.9517) corresponding to r is very large, so the result is not statistically significant. This means that there is not enough evidence that older creation dates explain the trend for higher cumulative global revenues for US IPs.
#
# Spearman's correlation shows a very weak, negative monotonic relationship between creation date and cumulative global revenue of US IPs, as the correlation coefficient ρ is -0.0257. This means that US IPs with older creation dates tends to have higher cumulative global revenues; because ρ has a greater absolute value than r, this suggests that the relationship is closer to being non-linear. The p-value (0.8989) corresponding to ρ is large, which means that the result is not statistically significant. This means that there is not enough evidence that older creation dates explain the trend for higher cumulative global revenues for US IPs.

# %% [markdown]
# ## Ethics

# %% [markdown]
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
# > There will be no human subjects in this project.
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# > There is no freely available U.S. merchandise revenue data for individual IPs, for both Japanese and U.S. franchises, so we estimate merchandise sales using a simple formula based on a published report. This can cause some bias because the revenue numbers come from different sources and may not be fully accurate for every franchise. Streaming accessibility data were also collected using the TMDb API, which does not always list streaming platforms correctly, especially for non-U.S. or region-specific IPs like Rilakkuma. Because of this, the accessibility of some franchises may be underestimated. To help reduce these issues, we use the same data collection method for all IPs, compare our revenue estimates with other public sources, and clearly note known gaps and limits in the TMDb data while using Wikipedia and its listed sources as our main reference.
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
# > We will not be dealing with PII in this project.
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# > Because our analysis focuses on franchise-level sales and engagement data rather than individual users, it does not involve protected demographic attributes. To mitigate downstream bias, we limit our conclusions to just market trends and will avoid making claims about specific populations or consumer groups (if it comes up).
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#
# > The data in this project will be stored in our group GitHub repo and will only be accessed by our group members.
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#
# > The public may message any of our group members to request any data to be removed. Each of our group members will include our contact information in our profiles.
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# > The repo may be kept online even after the class finishes. However, we are also open to deleting any data (or the repo for that matter) if deemed necessary.
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
# > In this project, though we are looking at sales data, I expect that there will be a cultural aspect in it too that plays a factor in the success of Japanese IPs. We plan to educate ourselves into the marketing approach, which may be cultural, employed by the Japanese franchises. We may make connections to the Japanese consumer behaviors and to their success. We plan to incorporate insights from media studies, industry reports and fan community discussions to give conteext to our findings.
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# > Since our project has a cultural aspect to it, we will strive to keep our analysis to be as close as possible to be derived from the data only, and provide context like consumer behavior when appropriate.
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
# > We will strive to be as honest and as objective as possible when presenting our data through visualization. We will choose the best type of visualization/graphs to present our data.
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
# > We will not be dealing with PII in this project.
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
# > We will ensure that our analysis will include sufficient explanation as to why certain models or approach were taken. We are also using GitHub which keeps logs to changes made in the project. When making commits to our project, we will ensure to include descriptive commit messages.
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#
# > We will limit our use of proxies. But we think that the Google-Trends based trends to measure fan engagement does not present unfair discriminatory representation, it will not be a proxy for individual demographic characteristics such as race, gender, or socioeconomic status.We will also be using
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
# > Fairness testing across different affected groups is not conducted in this project, as the analysis is descriptive and does not involve predictive modeling or group-level decision outcomes.
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#
# > We use both estimated merchandise sales and Google Trends data because they measure different things. Sales estimates show how much people are buying, while Google Trends shows how interested people are. Using both helps us avoid focusing too much on just one metric, and prevents our analysis from being too one dimensional.
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#
# > Our methods are easy to explain because we use simple calculations and public data sources like Wikipedia revenue lists and Google Trends. This makes it clear how we compare franchises and where our results come from.
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# > We will clearly explain the limits of our project, including that our sales numbers are estimates, that global revenue data is used to approximate U.S. sales, and that Google Trends is only a rough metric of fan interest.
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
# > No monitoring or post-deployment evaluation is planned, as this project is ONLY exploratory and we will not be deploying a model or generate real-world decisions.
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#
# > Our project does not affect people directly. If someone raises concerns about our results, we would review the data and fix any mistakes or misunderstandings.
#  - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
# >There is no production model to roll back in this project. Any issues identified can be resolved by updating the analysis or data and rerunning the code.
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
# > We know our results could be misunderstood. To prevent this, we clearly explain that our numbers are estimates and should not be used as exact sales data or predictions.

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# **Communication**
# Our team will use the Messages group chat for communication. A reasonable wait time to expect a response to a message is up to a few hours. We will meet at least once a week virtually on Zoom.
#
# **Tone**
# Team members come from different backgrounds and communication styles. To ensure productive and respectful collaboration, our team agrees to use respectful language and invite discussion rather than shutting it down. We will be direct and honest about concerns or disagreements, but frame criticism around ideas, data, or methods, and not people.
# Examples of appropriate tone
# * I think X is a problem because of Y. Does everyone else see it that way, too, or am I missing something?
# * I disagree with that idea because Z. What do you think if we try ___ instead?
#
# **Decision Making**
# To keep the project moving efficiently while respecting everyone’s input, for decision-making processes, we will use consensus for major project decisions and majority vote when needed. For technical decisions, the team member primarily responsible for that area has the right to make those decisions. If a decision must be made quickly and one or more team members are non-responsive after a reasonable time, the available team members may proceed.
#
# **Tasks**
# To balance efficiency, fairness, and learning, the team will have primary roles with flexibility. Team members may take on primary roles based on strengths and interests. However, everyone is encouraged to understand the full project beyond their main area and contribute when needed. Tasks will be assigned based on project priorities, individual availability, and relevant skills and goals.

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 2/1  | 10 AM  | Draft proposal sections (research question, background, hypothesis, data, ethics, team expectations)  | Edit and finalize project proposal, discuss room for improvement and missing components, assign work for project proposal imrpovement   |
# | 2/10  | 8 PM  | Get acceptable datasets, get Google Trends data and merchandise revenue data | Review dataset quality and limitations, discussion assumptions, plan data wrangling   |
# | 2/16  | 8 PM  | Clean and organize datasets, create tables and variables | Final review of data section, prepare and finalize Checkpoint #1 (data) |
# | 2/24  | 8 PM  | Finish exploratory data analysis(EDA) and initial visualizations| Review EDA results, refine initial visualizations, discuss emerging patterns and remaining steps for project completion |
# | 3/2  | 8 PM  | Finalize EDA results and visualizations | Submit Checkpoint #2 (EDA) |
# | 3/10  | 8 PM  | Complete analysis | Draft project narrative, do presentation video |
# | 3/16  | 8 PM  | Finalize report and presentation, record and edit video | Review and submit Final Project, Team Evaluation Survey and Course Survey |
