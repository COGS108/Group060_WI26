# %% [markdown]
# # Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
# Scoring: Out of 18 points in total.  15 points in the report.  3 points in the video summary of your report for a non-technical audience.
#
# For the report:
# - Each Developing  => -0.5 pts
# - Each Unsatisfactory/Missing => -1 pts
#   - until the score is 0
#
# For the video:
# - Developing  => -1.5 pts
# - Unsatisfactory/Missing => -3 pts
#
# |                                                                                    | Unsatisfactory                                                                                                                                                                                                                                                                                      | Developing                                                                                                                                                                                                                                                                                                                          | Proficient                                                                                                                                                                                                                                                    | Exellent                                                                                                                                                                                                                                                                                                                                                          |
# | ---------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Title & abstract                                                                   | Title or abstract is confusing or fails to offer important details about the question, variables, context, or methods of the project.                                                                                                                                                               | Title or abstract lacks relevance or fails to offer appropriate details about the question, variables, context, or methods of the project.                                                                                                                                                                                          | Title and abstract are relevant, offering sufficient details about the research project.                                                                                                                                                                      | Title and abstract are informative, succinct, and clear. It offers specific details about the question, variables, context, and proposed methods of the study.                                                                                                                                                                                                    |
# | Background                                                                         | Did not have at least 3 reliable and relevant sources. Or relevant sources were not used in relevant ways                                                                                                                                                                                           | A key component was not connected to the research literature. Selected literature was from unreliable sources. Literary supports were vague or ambiguous.                                                                                                                                                                           | Key research components were connected to relevant, reliable literature.                                                                                                                                                                                      | Narrative integrates critical and logical details from the peer-reviewed or other professional research literature. Each key research component is grounded to the literature. Attention is given to different perspectives, threats to validity, and opinion vs. evidence.                                                                                       |
# | Research question & hypothesis                                                     | Research issue remains unclear. The research purpose, questions, hypotheses, definitions or variables and controls are still largely undefined, or when they are are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Research issue is identified, but statement is too broad or fails to establish the importance of the problem. The research purpose, questions, hypotheses, definitions or variables and controls are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Identifies a relevant research issue. Research questions are succinctly stated, connected to the research issue, and supported by the literature. Variables and controls have been identified and described. Connections are established with the literature. | Presents a significant research problem related to the chemical sciences. Articulates clear, reasonable research questions given the purpose, design, and methods of the project. All variables and controls have been appropriately defined. Proposals are clearly supported from the research and theoretical literature. All elements are mutually supportive. |
# | Data description                                                                   | Did not have references to relevant data sources for this problem. Did not describe the data obtained at those sources                                                                                                                                                                              | A key data source was not referenced or described in satisfactory level of detail                                                                                                                                                                                                                                                   | All relevant data sources were referenced and described in terms of their key variables and size                                                                                                                                                              | Multiple data sources for each aspect of the project, All data sources are fully described and referenced. The details of the descriptions also make it clear how they support the needs ot the project.                                                                                                                                                          |
# | Data wrangling                                                                     | Data obviously not tidy and not clean. Or even if they are clean/tidy, there was no demonstration of that fact                                                                                                                                                                                      | Data has some minor problems with tidiness or cleanliness. Potentially these are not problems but it wasn't fully demonstrated to be the case in the code                                                                                                                                                                           | Data are made tidy and clean, or are clearly demonstrated to be so from download                                                                                                                                                                              | Data wrangling is complete, but also particularly thoroughly done for a very tough case. Often free text parsing is a bear like this, and doing it well can mean a million edge cases.                                                                                                                                                                            |
# | Data visualizations                                                                | Many plots don't capture useful information, or their display of information is difficult to understand.. Legends, labels, axes, titles, captions, etc of many plots may be poor or missing. Figures are not referenced in the main text.                                                           | Most plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are mostly legible and adequately describe the content of the figure. Most figures are referenced or explained inside the main text and not just left hanging.                                                                   | Plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are clearly legible and adequately describe the content of the figure. Figures are referenced or explained inside the main text and not just left hanging.      | Plots are beautiful and information dense. Legends, labels, axes, titles, captions, etc clearly describe the content of the figure. Figures are well integrated with the text.                                                                                                                                                                                    |
# | Data analysis and results                                                          | Lacks any metrics or at least metrics that are relevant to the problem                                                                                                                                                                                                                              | Some metrics selected are not appropriate for the problem or the metrics selected are not described sufficiently                                                                                                                                                                                                                    | All metrics described are appropriate and and described sufficiently                                                                                                                                                                                          | The metrics are described clearly and succinctly. Their appropriateness for addressing the research problem is clearly described.                                                                                                                                                                                                                                 |
# | Ethics                                                                             | Only tries a baseline model, never advances to proper model/hyper-parameter selection                                                                                                                                                                                                               | Only investigates one minimal aspect of their problem, e.g. just did a single hyperparameter selection on a single model                                                                                                                                                                                                            | Does a good model/hyper-parameter selection. Only attempts minimal secondary analysis                                                                                                                                                                         | Does a good model/hyper-parameter selection. Performs multiple secondary analysis such as learning curves, heat maps looking at where in the parameter space things are good/bad, uses statistical testing                                                                                                                                                        |
# | Conclusion and discussion                                                          | Doesn't have a narrative/conclusions of what the report accomplished. Or very minimal conclusions, like "X was best" without anything else                                                                                                                                                          | Has narrative/conclusions, but it feels perfunctory and lacks context. Especially if the limitations and ethics sections are largely junk or missing                                                                                                                                                                                | Properly recapitulates the results and provides context for them. Has a sense of the limitatins and ethical issues.                                                                                                                                           | Clearly recapitulates the results and provides context, including the literature/background Has a sense of what to do next, and has good explorations of the limitations and ethics.                                                                                                                                                                              |
# | Documentation and written communication                                            | Code documentation is non-existent or perfunctory. Writing has usage errors, poor fluency, and poor rhetoric. If doc/writing are both like this you get unsatisfacory. If one is unsatisfactory and the other is developing you still get unsatisfactory overall.                                   | Code documentation is only partially there. Writing has some usage errors, some poor fluency, or some poor rhetoric. If doc/writing are both like this you get developing. If one is developing and the other is satisfactory you still get developing.                                                                             | Code is documented throughout. Writing has good fluency, good rhetoric, and at most a few minor errors.                                                                                                                                                       | Code documentation is highly informative with docstrings. Writing is high quality. If both doc/writing are like this you get excellent. If one is satisfactory and the other excellent you still get satisfactory.                                                                                                                                                |
# | Video (developing -1.5 points, unsatisfactory -3 points)                           | Video well outside the 3-5min time range. Does not communicate major results at a non-technical level. Has major technical issues such as no sound or not available at link. Unsatisfactory if 2/3 of these are true                                                                                | Video just outside the 3-5min time range. Does not communicate well on some points (either wrong tech level or just confusing). Has technical issues such as poor speech quality on video. Developing if 2/3 of these are true                                                                                                      | Video has good quality and is in within 3-5 min range. Communicates the major results at an accessible level for non-technical people.                                                                                                                        | Video has high production quality and is in within 3-5 min range. Communicates the major results clearly and gives a sense of the methods at an accessible level for non-technical people. Has a wow factor (e.g. funny or original approach)                                                                                                                     |
# | Quality modifier (can result in extra credit beyond 18 points for this assignment) | Almost everything was just barely proficient. Lots of minimal effort work. Do not double punish; if they already lost points on the rubric do not invoke this: -0.5 points                                                                                                                        |                                                                                                                                                                                                                                                                                                                                     |                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                       More than 5 excellents on this rubric: +0.5 points                                                                                   |

# %% [markdown]
# # COGS 108 - Final Project (change this to your project's title)
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [`X`] YES - make available
# * [  ] NO - keep private
#
# ## Link to video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
#
# The United States has historically dominated the global entertainment market, with domestic intellectual properties (IPs) such as Marvel and Disney generating substantial global franchise revenue. However, in recent decades the global industry has experienced increasing competition from foreign IPs, particularly from Japan.  This project aims to evaluate the relationship between IP creation date, consumer engagement, and media exposure in order to determine which factor most strongly influences cumulative global revenue. It also examines how the influence of these factors differs between the U.S. and Japanese markets in terms of cumulative global revenue. The analysis was also performed separately for U.S. and Japanese IPs to compare differences between the two markets.
# The results show that media exposure has the strongest relationship with cumulative global revenue overall, while consumer engagement measured by search interest also shows a positive relationship with revenue. Meanwhile, IP creation date shows no meaningful relationship with revenue. When comparing markets, Japanese IPs show a stronger relationship between search interest and revenue, while U.S. IPs show a stronger relationship between media exposure and revenue. These results show that modern popularity and media presence influence franchise revenue more than the age of the IP.

# %% [markdown]
# ## Authors
#
# - Inigrid Wang: Research Question, Background, Data - Description, Merged Table, EDA - Search Interest (all countries & US), Discussion and Conclusion, Analysis of Correlation Strengths for Japanese IPs compared to US IPs
# - John Bolibol: Hypothesis, Ethics, Data - TMDb API, EDA - Media Exposure, Abstract, Discussion and Conclusion
# - Nathan Bustos Medina: Prior Work, Data - Google Trends, EDA - Search Interest (Japan)
# - Sophia Xie: Team Expectations, Data - IP Creation Date, EDA - Creation Date (all country & US), Analysis of Correlation Strengths for all IPs (regardless of country)
# - Szeying Chan: Timeline, Data - IP Global Revenue, EDA - Creation Date (Japan)

# %% [markdown]
# ## Research Question

# %% [markdown]
# Given the US’s deep integration with global popular culture - particularly Japanese IPs - how do factors like the creation date of IPs, consumer engagement, and media exposure correlate with historical IP performance in the global market? We measure IP performance by the individual IP's cumulative global revenue, consumer engagement by these IP's average search interest worldwide, and media exposure by the number of streaming platforms that carry content from that IP. Furthermore, when we look at US and Japanese IPs separately, how do these different factors contribute to their cumulative global revenue?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# While the US is one of the major entertainment markets in the world, its entertainment market is becoming increasingly dependent on imported IPs, which is evident as we see a 17.9% increase in the US demand for imported content in film and TV shows from 2019 to 2025.<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2) A contributer to this demand is Japanese IPs. Japan is known for its sustaining IPs, which can be seen with franchises such as Pokémon and One Piece that continue to have major commericial success even through the decades since these series have been released. In fact, Japan‘s anime market alone generated billions of dollars in annual revenue by the mid-2020s, and is still expected to grow due to domestic and international demand.<a name="cite_ref-4"></a>[<sup>4</sup>](#cite_note-4)
#
# This raises questions about the strength of domestic US IPs, including major franchises such as Disney and Marvel. With the increasingly globalized U.S. popular culture, American consumers are continuously attracted to foreign media such as anime, gearing their attention away from domestic IPs. This drives us to explore which how the three factors that we have identified in our research question contribute (possibly differently) to the cumulative global revenue of these IPs.
#
# There are no prior studies known to us that are directly related to our project. However, we did find some studies that can provide insight into the conclusion of our study. In 2025, the cultural differences between the marketing strategies by the United States vs the Japanese were explored.<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1) The findings exhibited that the US marketing strategies included an emphasis on bold self-expression and straight-forward, relatable advertising tactics. On the other hand, Japanese marketing tactics put more focus on storytelling, culture, family, and simplicity. They also focus on highlighting the craftsmanship and quality of their products. This may have some relation to the importance of brand loyalty in Japan compared to America. This emphasis on long-term relationships can be seen through the long-lasting dominance of brands such as Sony and Nintendo in Japanese society–and even amongst many Americans.
#
# Research exploring the behavior of both American and Japanese children and their relationship with advertisement showed that there were many differences between the two audiences.<a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3) In America, the children were more skeptical towards the advertisements and are more susceptible to direct messaging and reasoning. They also are more attracted to products that market towards the benefits of a child. In Japan, children are more vulnerable to advertisements and watch much less television. This means it is harder for them to recognize when something is an advertisement. Japanese children are more susceptible to emotional messaging that puts a larger emphasis towards the product benefitting their family’s needs.
#
# Two years ago, the Japanese IP-driven Merchandising Market in only the United States was roughly valued at 19.2 Billion USD and has been projected to grow at a CAGR (Compound Annual Growth Rate) of 11.7 percent.<a name="cite_ref-5"></a>[<sup>5</sup>](#cite_note-5) The catalyst of this significant rise would be the increased popularization of anime in streaming platforms like Netflix, Crunchyroll and Hulu. Meanwhile, out of the top 10 global licensors of 2025, 8 out of 10 of the companies were American.<a name="cite_ref-6"></a>[<sup>6</sup>](#cite_note-6) This includes the titan that is Disney–reaching 62 Billion USD globally.
#
# **Resources**
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Cox, E. (2025, July 7). Understanding the Cultural Differences in Marketing: U.S. vs. Japan | Hapatune. Hapatune. https://hapatune.com/understanding-the-cultural-differences-in-marketing-u-s-vs-japan/‌
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Flynn, K. (6 Dec 2025). U.S. demand for foreign films and shows hits all-time high. https://www.axios.com/media-trends-membership/2025/12/06/foreign-tv-streaming-demand
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) Gaumer, C., & Shah, A. (2004). Television Advertising and Child Consumer: Different Strategies for U.S. and Japanese Marketers. The Coastal Business Journal the Coastal Business Journal, 3(1), 3. https://digitalcommons.coastal.edu/cgi/viewcontent.cgi?article=1027&context=cbj
# 4. <a name="cite_note-4"></a> [^](#cite_ref-4) Grand View Research. (2025). Japan anime merchandising market size, share & trends analysis. https://www.grandviewresearch.com/press-release/japan-anime-merchandising-market-analysis
# 5. <a name="cite_note-5"></a> [^](#cite_ref-5) Japanese IP-driven Merchandise And Content Market, 2030. (2024). Grandviewresearch.com. https://www.grandviewresearch.com/industry-analysis/japanese-ip-driven-merchandise-content-market-report
# 6. <a name="cite_note-6"></a> [^](#cite_ref-6) License Global. (2023, July 27). The Top Global Licensors Report 2023 | LicenseGlobal. Www.licenseglobal.com. https://www.licenseglobal.com/rankings-lists/top-150-leading-licensors

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# Generally, we think that consumer engagement is most important and will correlate the strongest with the cumulative global revenue of IPs, because engaged customers spend more money on an IP. In our project, an old creation date does not necessarily mean high engagement over time, and media exposure through airing platforms only gives a chance for fans to be engaged, while search interest reflects engagement more directly.
#
# When we focus on US IPs, we expect media exposure to correlate the strongest with the global revenue of IPs for a simple reason——most US IPs are heavily dependent on TV/film adaptation when it comes to making money at a large scale.
#
# When we focus on Japanese IPs, we expect IP creation date to correlate the strongest with the global revenue of Japanese IPs. We reason this because of the following: Japanese IPs are famous for their serialized mangas. Creating manga pairs high labor demand with a low budget for workers, which means that progressing the same amount in story would take longer through a manga than with film. This often causes an IP created through manga to stay long-running, providing more time to sell merchandize and their corresponding anime to run even longer than the manga itself, which allows Japanese IPs take a stronger advantage of peak popularity and have more chances at peak popularity if the IP cools down for some periods (lower dependence on a few peak consumer engagement) when it comes to cumulative global revenue. Manga, given that it is graphic, gains popularity fairly easily in the main entertainment markets (US, Japan, China, and Korea); note that Japan, China, and Korea all share similar aspects of culture through historical ties and their respective entertainment industries all have a very active manga/manhwa/webtoon community. This characteristic of the manga medium allows Japanese IPs to gain significant popularity even before being adapted into TV/film (lowering dependence on media exposure).

# %% [markdown]
# ## Data

# %% [markdown]
# The datasets below are used to extract the independent variables that we are interested in exploring for our project. The dependent variable of interest is the cumulative global revenue of IPs.
#
# There are 3 independent variables that we are using:
#
# 1. Consumer Engagement - All-time average search interest per IP
#     > This will be measured using the Google Trends Dataset below.
#     > The units of measurement is (sum of monthly average search interest)/ (total number of months).
# 2. Media Exposure - Number of platforms that air the IP.
#     > This will be measured using the TMDb API below.
#     > The units of measurement is just a single integer.
# 3. Creation Date - Earliest year on which the IP was released, regardless of publicizing medium.
#     > This will be measured using the Wikipedia dataset below.
#     > The units of measurement is the year.

# %% [markdown]
# ### Data overview
# - Dataset #1
#   - Dataset Name: Worldwide search interest of top 27 highest-grossing Japanese IPs and US IPs
#   - Note: We requested the data ourselves from Google Trends at the link https://trends.google.com/trends/. Google Trends
#     returned the data as a csv. We stored the csv on the repository belonging to a member of our team (username: spiianch).
#   - Link to the dataset: https://raw.githubusercontent.com/spiianch/cogs108_googletrends27/refs/heads/main/cogs108_googletrends27%20-%20time_series_Worldwide_20031231-1600_20260301-0149.csv
#   - Number of observations: 14098
#   - Number of variables: 3
#   - Description of the variables most relevant to this project:
#         Variables—Topic name, week, search interest.
#         We are using worldwide data from 2004-present, with 2004 being the earliest time that Google Trends can track.
#         The search interest ranges from 0-100 instead of exact counts because Google Trends normalizes search interest for
#         specific topics (IPs in our case) to its peak in the timeframe we specify, where 100 is the highest level of interest
#         and 0 is the lowest. Each row of data shows the search interest that month.
#
# - Dataset #2
#   - Dataset Name: Japanese IP Global Revenue & Creation Date
#   - Link to the dataset: https://en.wikipedia.org/wiki/List_of_highest-grossing_media_franchises#cite_note-270
#   - Number of observations: 27
#   - Number of variables: 3
#   - Description of the variables most relevant to this project:
#     Variables—IP name, global revenue in USD, and creation date.
#     The link we provided ranks the top grossing Japanese IPs by their cumulative global revenue. All
#     the variables included in the dataset are franchise, year, revenue in billions of dollars, original medium that the IP was
#     published in, and the owner of the IP.
#
# - Dataset #3
#   - Dataset Name: US IP Global Revenue & Creation Date
#   - Link to the dataset: https://en.wikipedia.org/wiki/List_of_highest-grossing_media_franchises#cite_note-270
#   - Number of observations: 27
#   - Number of variables: 3
#   - Description of the variables most relevant to this project:
#     Variables—IP name, global revenue in USD, and creation date.
#     The link we provided ranks the top grossing US IPs by their cumulative global revenue. All
#     the variables included in the dataset are franchise, year, revenue in billions of dollars, original medium that the IP was
#     published in, and the owner of the IP.
#
# - Dataset #4
#   - Dataset Name: Global number of streaming platforms carrying an IP
#   - Note: Data were collected using the TMDb API. Broad IPs (e.g., Disney Princess, Marvel) were broken down into their individual films and television series to improve search results. Franchises with multiple movies or seasons were further expanded using different official titles to capture all relevant entries.
#   - Number of observations: 19
#   - Number of variables: 2
#   - Description of key variables: This project focuses on two variables: the IP name and how many streaming platforms carry content from that IP. The number of platforms is used as a measure of how accessible each IP is to viewers.
#   - Descriptions of any shortcomings this dataset has with respect to the project:
#     This dataset was created using the TMDb API rather than downloaded directly, so it depends on how complete and accurate TMDb’s information is. Some search results may be loosely related to an IP, which adds noise to the data. Streaming provider information is also missing for some IPs, especially non-U.S. content. For example, Rilakkuma has limited provider data in TMDb despite being available on major streaming platforms, which may lead to its accessibility being underestimated.

# %% [markdown]
# ### Merged DataFrame
#
# We combined all our dataframes into one dataframe. In the dataframe below, we can access one IP per row and each column provides a different metric (revenue, creation date, streaming accessibility, etc.) with the exception of search interest, as that makes the dataframe hard to read. Leaving out search interest makes it easier for the parts in our data analysis that do not use search interest data.
#
# However, in the section following this one, we will include search interest in our dataframe and create a full dataframe with all metrics used in our study. This will be useful for the part in our analysis that uses search interest data.
#
# To see the code responsible for wrangling the data see `02-EDACheckpoint.ipynb`. From here on we will simply load the processed data for further analysis.

# %%
import os
os.listdir()
os.listdir("data")
# Out:
# ['ip_accessibility.csv',
#  '.ipynb_checkpoints',
#  'highest_grossing_media_franchises.csv',
#  '02-processed',
#  '01-interim',
#  '00-raw',
#  'cogs108_googletrends (2).csv',
#  'README.md']

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION 
import pandas as pd
merged_table = pd.read_csv("data/02-processed/merged_table.csv")
merged_table
# Out:
#                           Franchise  Creation Date  Revenue (Billion USD)  \
# 0                          Anpanman           1973                  38.40
# 1                       Hello Kitty           1974                  33.50
# 2                           Pac-Man           1980                  15.43
# 3                    Space Invaders           1978                  13.90
# 4                       Dragon Ball           1984                  10.70
# 5                    Street Fighter           1987                  10.70
# 6                         Rilakkuma           2003                  10.00
# 7                    Monster Strike           2013                  10.00
# 8    Demon Slayer: Kimetsu no Yaiba           2016                  10.00
# 9                             Mario           1981                   8.75
# 10     Super Sentai / Power Rangers           1975                   8.67
# 11          Ultra Series (Ultraman)           1966                   7.40
# ...

# %% [markdown]
# ### Full DataFrame with Search Interest
# The dataframe below builds on the merged dataframe above, but includes each IP's monthly search interests from Google Trends. In the dataframe, each row contains the month (dating from 2004 to present), the actual search interest of the IP in that month, IP name, and all the other metrics that were included in the previous dataframe.

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION 
full_table = pd.read_csv("data/02-processed/full_table.csv")
full_table
# Out:
#           Franchise Country  Creation Date  Revenue (Billion USD)  \
# 0       Angry Birds      US           2009                   9.54
# 1          Anpanman   Japan           1973                  38.40
# 2         Astro Boy   Japan           1952                   3.00
# 3            Barbie      US           1987                  36.30
# 4          Beyblade   Japan           1999                   4.60
# ...             ...     ...            ...                    ...
# 14093     Toy Story      US           1995                  14.80
# 14094      Ultraman   Japan           1966                   7.40
# 14095      Warcraft      US           1994                  12.40
# 14096  Yo-kai Watch   Japan           2013                   2.09
# 14097     Yu-Gi-Oh!   Japan           1996                   5.42
#
#        Number of Platforms       Month  Interest Value
# 0                     76.0  2004-01-01               0
# 1                     13.0  2004-01-01               0
# ...

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# To see the code responsible for EDA analyses see `02-EDACheckpoint.ipynb`.

# %% [markdown]
# ### Visualization of Independent Variable Frequencies

# %% [markdown]
# We will show the frequency of each variable with respect to each IP that we are using. We will do this for consumer engagement, media exposure, and creation date, in this order.
# - Frequency Chart for Creation Date
# - Frequency Chart for Consumer Engagement
# - Frequency Chart for Media Exposure
#
#
# We included frequency charts to better understand how each independent variable is distributed in our dataset before interpreting the correlation results. These charts show how often different values of search interest, creation date, and media exposure appear in the data. This helps us see patterns such as whether most values are grouped together, spread out, or if there are any unusual values. Understanding these patterns is important because extreme values or uneven data can affect correlation analyses like Pearson and Spearman. We also compare the frequency charts for U.S. and Japanese IPs to see whether the variables are distributed differently between the two groups, which helps us better interpret our correlation results.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

counts = full_table["Interest Value"].value_counts().sort_index()
counts = counts.reindex(range(0, 101), fill_value=0)

plt.figure(figsize=(10,5))

plt.bar(counts.index, counts.values)

plt.xlabel("Interest Value (0–100)")
plt.ylabel("Frequency")
plt.title("Frequency of Interest Values based on Google Trends")

plt.xticks(range(0,101,10))

plt.show()

plt.figure(figsize=(10,5))

ax = sns.countplot(
    data=merged_table,
    x="Creation Date",
    order=sorted(merged_table["Creation Date"].unique()),
    color="skyblue"
)

ax.yaxis.set_major_locator(MaxNLocator(integer=True))

plt.xticks(rotation=90)
plt.xlabel("Creation Year")
plt.ylabel("Frequency")
plt.title("Frequency of IP Creation Dates")

plt.show()

plt.figure(figsize=(10,5))

ax = sns.countplot(
    data=merged_table,
    x="Creation Date",
    hue="Country",
    order=sorted(merged_table["Creation Date"].unique())
)

ax.yaxis.set_major_locator(MaxNLocator(integer=True))

plt.xticks(rotation=90)
plt.xlabel("Creation Year")
plt.ylabel("Frequency")
plt.title("Frequency of IP Creation Dates by Country")

plt.show()

plt.figure(figsize=(10,5))

ax = sns.countplot(
    data=merged_table,
    x="Number of Platforms"
)

ax.yaxis.set_major_locator(MaxNLocator(integer=True))

plt.xlabel("Number of Streaming Platforms")
plt.ylabel("Frequency")
plt.title("Frequency of Media Exposure (Number of Streaming Platforms)")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Correlation Relationship with IPs (regardless of country)
# Below, we will examine the correlation relationship when taking all IPs in our dataset into consideration, which will provide insight about which variable has the strongest positive correlation with cumulative global revenue for IPs in general. We will produce three scatterplots, each exploring the relationship between a different pair of variables. We will apply both the Pearson and Spearman's correlation for each scatterplot to examine the relationship between each pair of variables.
#
# 1. Average Search Interest (x-variable) vs Cumulative Global Revenue (y-variable)
# 2. Media Exposure (x-variable) vs Cumulative Global Revenue (y-variable)
# 3. Creation Date (x-variable) vs Cumulative Global Revenue (y-variable)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# paths to the images
images = [
    "results/search_vs_revenue_all.png",
    "results/media_vs_revenue_all.png",
    "results/creation_vs_revenue_all.png"
]

fig, axes = plt.subplots(3, 1, figsize=(7,16))

for ax, path in zip(axes, images):
    img = mpimg.imread(path)
    ax.imshow(img)
    ax.axis("off")  # removes axes and ticks

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Correlation Relationship with Japanese IPs
# Below, we will examine the correlation relationship when looking at only Japanese IPs in our dataset, and look at which variable has the strongest positive correlation with cumulative global revenue for Japanese IPs. We will produce three scatterplots, each exploring the relationship between a different pair of variables. We will also apply both the Pearson and Spearman's correlation for each scatterplot to examine the relationship between each pair of variables.
#
# 1. Average Search Interest (x-variable) vs Cumulative Global Revenue (y-variable)
# 2. Media Exposure (x-variable) vs Cumulative Global Revenue (y-variable)
# 3. Creation Date (x-variable) vs Cumulative Global Revenue (y-variable)

# %%
# paths to the images
images = [
    "results/search_vs_revenue_jp.png",
    "results/media_vs_revenue_jp.png",
    "results/creation_vs_revenue_jp.png"
]

fig, axes = plt.subplots(3, 1, figsize=(7,16))

for ax, path in zip(axes, images):
    img = mpimg.imread(path)
    ax.imshow(img)
    ax.axis("off")  # removes axes and ticks

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Correlation Relationship with US IPs
# Below, we will examine the correlation relationship when only looking at US IPs in our dataset, and look at which variable has the strongest positive correlation with cumulative global revenue for US IPs. We will produce three scatterplots, each exploring the relationship between a different pair of variables. We will also apply both the Pearson and Spearman's correlation for each scatterplot to examine the relationship between each pair of variables.
#
# 1. Average Search Interest (x-variable) vs Cumulative Global Revenue (y-variable)
# 2. Media Exposure (x-variable) vs Cumulative Global Revenue (y-variable)
# 3. Creation Date (x-variable) vs Cumulative Global Revenue (y-variable)

# %%
# paths to the images
images = [
    "results/search_vs_revenue_us.png",
    "results/media_vs_revenue_us.png",
    "results/creation_vs_revenue_us.png"
]

fig, axes = plt.subplots(3, 1, figsize=(7,16))

for ax, path in zip(axes, images):
    img = mpimg.imread(path)
    ax.imshow(img)
    ax.axis("off")  # removes axes and ticks

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Analysis of Correlation Strengths for all IPs (regardless of country)
#
# To see code used to compute the pearson and spearman correlation coefficients and their respective p-values, please see `02-EDACheckpoint.ipynb`.
#
# The correlation coefficients and their respective p-values are stored in .txt files stored in results/ directory. Namely, overall_correlation.txt, japan_correlation.txt, us_correlation.txt.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION
with open("results/overall_correlation.txt", "r") as f:
    contents = f.read()

print(contents)
# Out:
# Average Search Interest vs Cumulative Global Revenue per IP
# Pearson r = 0.1990, p-value = 0.1530
# Spearman ρ = 0.3456, p-value = 0.0113
#
# Media Exposure vs Cumulative Global Revenue per IP
# Pearson r = 0.3349, p-value = 0.0163
# Spearman ρ = 0.2356, p-value = 0.0961
#
# Creation Date vs Cumulative Global Revenue per IP
# Pearson r = -0.0899, p-value = 0.5221
# Spearman ρ = -0.0886, p-value = 0.5283

# %%
import numpy as np
import matplotlib.pyplot as plt

# Correlation results for overall IPs
corr_data = pd.DataFrame({
    'Variable': ['Avg Interest','Media Exposure','Creation Date'],
    'Pearson r': [0.1990, 0.3349, -0.0899],
    'Pearson p': [0.1530, 0.0163, 0.5221],
    'Spearman r': [0.3456, 0.2356, -0.0886],
    'Spearman p': [0.0113, 0.0961, 0.5283]
})

# Function to add stars for significance
def significance_star(p):
    if p < 0.01:
        return '**'
    elif p < 0.07:  # slightly higher threshold
        return '*'
    else:
        return ''

x = np.arange(len(corr_data))
width = 0.35

fig, ax = plt.subplots(figsize=(8,5))

# Pearson bars
ax.bar(x - width/2, corr_data['Pearson r'], width, color='skyblue', label='Pearson r')
# Spearman bars
ax.bar(x + width/2, corr_data['Spearman r'], width, color='salmon', label='Spearman ρ')

# Add stars above bars
for i in range(len(corr_data)):
    ax.text(x[i] - width/2, corr_data['Pearson r'][i] + 0.02, 
            significance_star(corr_data['Pearson p'][i]),
            ha='center', va='bottom', fontsize=12)
    ax.text(x[i] + width/2, corr_data['Spearman r'][i] + 0.02, 
            significance_star(corr_data['Spearman p'][i]),
            ha='center', va='bottom', fontsize=12)

# Labels
ax.set_xticks(x)
ax.set_xticklabels(corr_data['Variable'])
ax.set_ylabel('Correlation')
ax.set_title('Overall IP: Correlation of Variables vs Cumulative Global Revenue')
ax.axhline(0, color='gray', linewidth=0.8)
ax.legend()
plt.ylim(-0.1, 0.4)  # adjust y-axis for visibility
plt.tight_layout()
plt.show()

# %% [markdown]
# When comparing average search interest with cumulative global revenue, the Pearson r = 0.1990 indicates a weak positive linear relationship, and the Spearman ρ = 0.3456 indicates a moderate positive monotonic relationship. Both correlations are positive, meaning that IPs with higher search interest tend to have higher revenue. The Pearson p-value = 0.1530 is not statistically significant, and the Spearman p-value = 0.0113 is statistically significant. The fact that Spearman is stronger and significant suggests that revenue tends to increase with search interest in rank order, but the relationship is not always proportional. Search popularity is an indicator of IP success, but it only explains part of the revenue differences. When people frequently search for a franchise, it shows high fan engagement, active marketing campaigns, and new releases, which increase the likelihood that people will use or buy franchise products.
#
# For media exposure and cumulative global revenue, the Pearson r = 0.3349 shows a moderate positive linear relationship, while the Spearman ρ = 0.2356 shows a weak monotonic relationship. The positive correlations mean that IPs with more media exposure tend to generate more revenue. The Pearson p-value = 0.0163 is statistically significant, and the Spearman p-value = 0.0961 is not statistically significant, so media exposure appears to have some linear relationship with revenue. The weaker Spearman correlation suggests that the relationship may be influenced by outliers from the large franchises. Franchises that expand across movies, TV shows, games, merchandise, and books, etc. tend to accumulate greater revenue. There are more consumer entry points and different media that reach broader demographics.
#
# For the creation date and cumulative global revenue, the Pearson r = -0.0899 and Spearman ρ = -0.0886 are slightly negative, so older franchises might have a slightly higher revenue. But the correlations are extremely weak. Both p-values are very large, so the relationship is not statistically significant. There is no meaningful relationship between the IP creation date and total revenue. Older franchises are not guaranteed to earn more money, and new franchises can achieve high revenue quickly.
#
# Overall, media exposure is the strongest predictor of revenue for all the IPs. Search interest also relates to revenue, while IP creation date has no effect. This demonstrates that modern popularity and cross-media expansion matter more than age for determining revenue.

# %% [markdown]
# ### Analysis of Correlation Strengths for Japanese IPs compared to US IPs
#
# To see code used to compute the pearson and spearman correlation coefficients and their p-values, please refer to 02-EDACheckpoint.ipynb.
#
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.  Every project will be different here... but some examples of analyses are: inferential statistics where you calculate p-values (like a t-test or a Monte Carlo simulation), regression models, or a machine learning model

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION
with open("results/japan_correlation.txt", "r") as f:
    contentsjp = f.read()
title = "Japanese IP"
print(title)
print("-" * len(title))
print(contentsjp)

with open("results/us_correlation.txt", "r") as f:
    contentsus = f.read()
title = "US IP"
print(title)
print("-" * len(title))
print(contentsus)
# Out:
# Japanese IP
# -----------
# Average Search Interest vs Cumulative Global Revenue per Japanese IP
# Pearson r = 0.0554, p-value = 0.0000
# Spearman ρ = 0.2596, p-value = 0.0000
#
# Media Exposure vs Cumulative Global Revenue per Japanese IP
# Pearson r = -0.2504, p-value = 0.2380
# Spearman ρ = -0.0403, p-value = 0.8519
#
# Creation Date vs Cumulative Global Revenue per Japanese IP
# Pearson r = -0.2540, p-value = 0.2105
# Spearman ρ = -0.2697, p-value = 0.1827
#
#
# US IP
# -----
# Average Search Interest vs Cumulative Global Revenue per US IP
# Pearson r = 0.0798, p-value = 0.6925
# Spearman ρ = 0.0488, p-value = 0.8088
#
# Media Exposure vs Cumulative Global Revenue per US IP
# Pearson r = 0.3599, p-value = 0.0652
# Spearman ρ = 0.0776, p-value = 0.7006
#
# Creation Date vs Cumulative Global Revenue per US IP
# Pearson r = 0.0122, p-value = 0.9517
# Spearman ρ = -0.0257, p-value = 0.8989

# %%
# Correlation results for US IPs
corr_data = pd.DataFrame({
    'Variable': ['Avg Interest','Media Exposure','Creation Date'],
    'Pearson r': [0.0798, 0.3599, 0.0122],
    'Pearson p': [0.6925, 0.0652, 0.9517],
    'Spearman r': [0.0488, 0.0776, -0.0257],
    'Spearman p': [0.8088, 0.7006, 0.8989]
})

def significance_star(p):
    # Treat p ≤ 0.07 as significant for this case
    if p < 0.01:
        return '**'
    elif p < 0.07:   # slightly higher threshold
        return '*'
    else:
        return ''

x = np.arange(len(corr_data))  # 0,1,2 for x-axis
width = 0.35  # width of bars

fig, ax = plt.subplots(figsize=(8,5))

# Pearson bars
pearson_bars = ax.bar(x - width/2, corr_data['Pearson r'], width, color='skyblue', label='Pearson r')
# Spearman bars
spearman_bars = ax.bar(x + width/2, corr_data['Spearman r'], width, color='salmon', label='Spearman ρ')

# Add stars above bars
for i in range(len(corr_data)):
    # Pearson stars
    ax.text(x[i] - width/2, corr_data['Pearson r'][i] + 0.02, 
            significance_star(corr_data['Pearson p'][i]),
            ha='center', va='bottom', fontsize=12)
    # Spearman stars
    ax.text(x[i] + width/2, corr_data['Spearman r'][i] + 0.02, 
            significance_star(corr_data['Spearman p'][i]),
            ha='center', va='bottom', fontsize=12)

# Labels
ax.set_xticks(x)
ax.set_xticklabels(corr_data['Variable'])
ax.set_ylabel('Correlation')
ax.set_title('US IP: Correlation of Variables vs Cumulative Global Revenue')
ax.axhline(0, color='gray', linewidth=0.8)  # zero line
ax.legend()
plt.ylim(-0.1, 0.5)
plt.tight_layout()
plt.show()

# %%
# Correlation results for Japanese IPs
corr_data = pd.DataFrame({
    'Variable': ['Avg Interest','Media Exposure','Creation Date'],
    'Pearson r': [0.0554, -0.2504, -0.2540],
    'Pearson p': [0.0000, 0.2380, 0.2105],
    'Spearman r': [0.2596, -0.0403, -0.2697],
    'Spearman p': [0.0000, 0.8519, 0.1827]
})

# Function to add stars for significance
def significance_star(p):
    if p < 0.01:
        return '**'
    elif p < 0.07:   # slightly higher threshold for marginal significance
        return '*'
    else:
        return ''

x = np.arange(len(corr_data))
width = 0.35

fig, ax = plt.subplots(figsize=(8,5))

# Pearson bars
ax.bar(x - width/2, corr_data['Pearson r'], width, color='skyblue', label='Pearson r')
# Spearman bars
ax.bar(x + width/2, corr_data['Spearman r'], width, color='salmon', label='Spearman ρ')

# Add stars above bars
for i in range(len(corr_data)):
    ax.text(x[i] - width/2, corr_data['Pearson r'][i] + 0.02, 
            significance_star(corr_data['Pearson p'][i]),
            ha='center', va='bottom', fontsize=12)
    ax.text(x[i] + width/2, corr_data['Spearman r'][i] + 0.02, 
            significance_star(corr_data['Spearman p'][i]),
            ha='center', va='bottom', fontsize=12)

# Labels
ax.set_xticks(x)
ax.set_xticklabels(corr_data['Variable'])
ax.set_ylabel('Correlation')
ax.set_title('Japanese IP: Correlation of Variables vs Cumulative Global Revenue')
ax.axhline(0, color='gray', linewidth=0.8)
ax.legend()
plt.ylim(-0.3, 0.3)  # adjust y-axis for visibility
plt.tight_layout()
plt.show()

# %% [markdown]
# Average search interest, media exposure, and creation date all have a similar correlation strength with cumulative global revenue for Japanese IPs. However, average search interest has the strongest positive correlation, and has a very low p-value (0.0000 in when printing 4 digits past the decimal), so this correlation relationship is statistically significant. This means that average search interest does explain the positive trend in cumulative global revenue for Japanese IPs. Because the biggest positive correlation coefficient (0.2596) is from the Spearman's correlation, this means that there is a moderate, positive nonlinear relationship between average search interest and cumulative global revenue for Japanese IPs.
#
# For US IPs, media exposure has the strongest correlation relationship with cumulative global revenue per US IP. That is seen with the Pearson correlation coefficient of 0.3599, showing a moderate, positive linear relationship between meia exposure and the cumulative global revenue for US IPs. It is paired with a reasonably low p-value of 0.0652, and thus we believe that media exposure does explain the positive trend in cumulative global revenue for US IPs.
#
#
#
# In context, Japanese IPs are more reliant on average search interest, while US IPs are more reliant on media exposure.
#
# Given the small correlation coefficients for US IPs average search interest globally, we think that US IPs are more popular within the US, and the highest grossing IPs gain popularity mainly through moving media (ex. TV/Film). Given the large production budgets and production time of TV/Film before release even for series, the popularity is not sustained enough to contribute enoguh average search interest that positively correlates with cumulative global revenue for US IPs. The US is not known for retail manufacturing, do not have a mature merchandize line to sustain the popularity of IPs during peak times, causing US IPs loses a lot of merchandize profit compared to Japanese IPs. We guess this because while Japanese series are highly popularity for merchandize, popular TV shows like Hunger Games are famous for the show content, but we rarely see people wearing the merchandize or even unpack it online; it seems more like there is an absence of effective merchandize for these big US serialized IPs in general.
#
# For the Japanese IPs, there are two IPs that have a cumulative global revenue that is a lot higher than the rest of the IPs. Hence, they are likely contributing to a higher Spearman's correlation value. We expect the impact of media exposure and creation date on cumulative global revenue to be a lot smaller if we disregard all these two datapoints. Hence, the only correlation that would have a significant correlation coefficient is average search interest. We think that Japanese IPs are better at maintaining interest in an IP over a given period of time, as they are reliant not only on the TV/film medium. When there are no series airing, there are still the manga series that has a new update usually at least once per month. In addition, they are many news on merchandize such has pop-stores and a very active anime fandom that reinforces interest in these IPs. The number of streaming platforms may not matter as much, as Netflix primarily dominates the streaming market, while Crunchyroll is probably the only other platform that can compare with its popularity for Japanese animes.

# %% [markdown]
# ### Regression Analysis

# %%
avg_df = (
    full_table
    .groupby('Franchise', as_index=False)
    .agg({
        'Country': 'first',
        'Interest Value': 'mean',
        'Revenue (Billion USD)': 'first',
        'Number of Platforms': 'first',
        'Creation Date': 'first'
    })
)
avg_df = avg_df.rename(columns={'Interest Value': 'Avg Search Interest'})
avg_df = avg_df.replace([np.inf, -np.inf], np.nan)  # convert inf → NaN
avg_df = avg_df.dropna()  # drop rows with any NaNs

avg_df
# Out:
#                           Franchise Country  Avg Search Interest  \
# 0                       Angry Birds      US             0.605263
# 1                          Anpanman   Japan             0.000000
# 2                         Astro Boy   Japan             0.000000
# 3                          Avengers      US             0.669173
# 4                            Barbie      US             4.883459
# 5                            Batman      US             1.665414
# 6                          Beyblade   Japan             0.116541
# 7                      Call Of Duty      US             3.022556
# 8                       Candy Crush      US             0.571429
# 9                              Cars      US             0.210526
# 10   Demon Slayer: Kimetsu No Yaiba   Japan             0.714286
# 11          Despicable Me (Minions)      US             0.556391
# 12                  Disney Princess      US             0.191729
# ...

# %% [markdown]
# #### Overall Regression

# %%
import statsmodels.api as sm

def run_regression(df, label):
    
    X = df[['Avg Search Interest','Number of Platforms','Creation Date']]
    X = sm.add_constant(X)
    
    y = df['Revenue (Billion USD)']
    
    model = sm.OLS(y, X).fit()
    
    print(f"\n===== {label} Regression =====")
    print(model.summary())
    
    return model

model_overall = run_regression(avg_df, "Overall")
# Out:
# ===== Overall Regression =====
#                               OLS Regression Results
# ...
# Dep. Variable:     Revenue (Billion USD)   R-squared:                       0.155
# Model:                               OLS   Adj. R-squared:                  0.101
# Method:                    Least Squares   F-statistic:                     2.879
# Date:                   Sat, 14 Mar 2026   Prob (F-statistic):             0.0458
# Time:                           05:33:14   Log-Likelihood:                -192.72
# No. Observations:                     51   AIC:                             393.4
# Df Residuals:                         47   BIC:                             401.2
# Df Model:                              3
# Covariance Type:               nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %% [markdown]
# #### US Regression

# %%
us_df = avg_df[avg_df['Country'] == 'US']

model_us = run_regression(us_df, "US")
# Out:
# ===== US Regression =====
#                               OLS Regression Results
# ...
# Dep. Variable:     Revenue (Billion USD)   R-squared:                       0.179
# Model:                               OLS   Adj. R-squared:                  0.072
# Method:                    Least Squares   F-statistic:                     1.675
# Date:                   Sat, 14 Mar 2026   Prob (F-statistic):              0.200
# Time:                           05:33:14   Log-Likelihood:                -99.855
# No. Observations:                     27   AIC:                             207.7
# Df Residuals:                         23   BIC:                             212.9
# Df Model:                              3
# Covariance Type:               nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %% [markdown]
# #### Japan Regression

# %%
jp_df = avg_df[avg_df['Country'] == 'Japan']

model_jp = run_regression(jp_df, "Japan")
# Out:
# ===== Japan Regression =====
#                               OLS Regression Results
# ...
# Dep. Variable:     Revenue (Billion USD)   R-squared:                       0.189
# Model:                               OLS   Adj. R-squared:                  0.068
# Method:                    Least Squares   F-statistic:                     1.557
# Date:                   Sat, 14 Mar 2026   Prob (F-statistic):              0.231
# Time:                           05:33:14   Log-Likelihood:                -84.116
# No. Observations:                     24   AIC:                             176.2
# Df Residuals:                         20   BIC:                             180.9
# Df Model:                              3
# Covariance Type:               nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Ethics

# %% [markdown]
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
# > There will be no human subjects in this project.
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# > There is no freely available U.S. merchandise revenue data for individual IPs, for both Japanese and U.S. franchises, so we estimate merchandise sales using a simple formula based on a published report. This can cause some bias because the revenue numbers come from different sources and may not be fully accurate for every franchise. Streaming accessibility data were also collected using the TMDb API, which does not always list streaming platforms correctly, especially for non-U.S. or region-specific IPs like Rilakkuma. Because of this, the accessibility of some franchises may be underestimated. To help reduce these issues, we use the same data collection method for all IPs, compare our revenue estimates with other public sources, and clearly note known gaps and limits in the TMDb data while using Wikipedia and its listed sources as our main reference.
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
# > We will not be dealing with PII in this project.
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# > Because our analysis focuses on franchise-level sales and engagement data rather than individual users, it does not involve protected demographic attributes. To mitigate downstream bias, we limit our conclusions to just market trends and will avoid making claims about specific populations or consumer groups (if it comes up).
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#
# > The data in this project will be stored in our group GitHub repo and will only be accessed by our group members.
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#
# > The public may message any of our group members to request any data to be removed. Each of our group members will include our contact information in our profiles.
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# > The repo may be kept online even after the class finishes. However, we are also open to deleting any data (or the repo for that matter) if deemed necessary.
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
# > In this project, though we are looking at sales data, I expect that there will be a cultural aspect in it too that plays a factor in the success of Japanese IPs. We plan to educate ourselves into the marketing approach, which may be cultural, employed by the Japanese franchises. We may make connections to the Japanese consumer behaviors and to their success. We plan to incorporate insights from media studies, industry reports and fan community discussions to give conteext to our findings.
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# > Since our project has a cultural aspect to it, we will strive to keep our analysis to be as close as possible to be derived from the data only, and provide context like consumer behavior when appropriate.
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
# > We will strive to be as honest and as objective as possible when presenting our data through visualization. We will choose the best type of visualization/graphs to present our data.
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
# > We will not be dealing with PII in this project.
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
# > We will ensure that our analysis will include sufficient explanation as to why certain models or approach were taken. We are also using GitHub which keeps logs to changes made in the project. When making commits to our project, we will ensure to include descriptive commit messages.
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#
# > We will limit our use of proxies. But we think that the Google-Trends based trends to measure fan engagement does not present unfair discriminatory representation, it will not be a proxy for individual demographic characteristics such as race, gender, or socioeconomic status.We will also be using
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
# > Fairness testing across different affected groups is not conducted in this project, as the analysis is descriptive and does not involve predictive modeling or group-level decision outcomes.
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#
# > We use both estimated merchandise sales and Google Trends data because they measure different things. Sales estimates show how much people are buying, while Google Trends shows how interested people are. Using both helps us avoid focusing too much on just one metric, and prevents our analysis from being too one dimensional.
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#
# > Our methods are easy to explain because we use simple calculations and public data sources like Wikipedia revenue lists and Google Trends. This makes it clear how we compare franchises and where our results come from.
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# > We will clearly explain the limits of our project, including that our sales numbers are estimates, that global revenue data is used to approximate U.S. sales, and that Google Trends is only a rough metric of fan interest.
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
# > No monitoring or post-deployment evaluation is planned, as this project is ONLY exploratory and we will not be deploying a model or generate real-world decisions.
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#
# > Our project does not affect people directly. If someone raises concerns about our results, we would review the data and fix any mistakes or misunderstandings.
#  - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
# >There is no production model to roll back in this project. Any issues identified can be resolved by updating the analysis or data and rerunning the code.
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
# > We know our results could be misunderstood. To prevent this, we clearly explain that our numbers are estimates and should not be used as exact sales data or predictions.

# %% [markdown]
# ## Discussion and Conclusion
#
# Wrap it all up here.  Somewhere between 3 and 10 paragraphs roughly.
# 1. Summarize the important results you made
#    > This project examined how IP creation data, consumer engagement, and media exposure relate to cumulative global revenue for the top 27 IPs in the Japanese and US markets. Using Pearson and Spearman correlation analyses, we found that media exposure had the strongest relationship with revenue overall. Meanwhile, consumer engagement measured through search interest also showed a positive relationship with revenue. In contrast, IP creation date showed no meaningful correlation with cimulative global revenue. These results suggest that factors relation to current popularity and visibility matter more for revenue than how old an IP is.
# 2. This is a good time to refer back to your Background section and review how this work extended the previous stuff.
#    >In the background section, we discussed how the global entertainment industry has traditionally been dominated by major U.S. franchises, but foreign IPs, especially Japanese ones, have become more popular in recent years. This project builds on that idea by examining which measurable factors may help explain why some franchises generate more revenue than others. By comparing engagement, media exposure, and creation date, this study provides a clearer look at how different factors may contribute to the financial success of entertainment IPs.
# 3. Try to bring all the different results together into a bigger picture... what have we learned?
#    >Looking at the results overall, we learned that keeping people interested in a franchise appears to be more important than how old the IP is. Consumer engagement and media visibility and easier accessibility both showed stronger relationships with revenue than creation date. This suggests that ongoing audience interest and exposure across different media platforms may play a larger role in the success of an IP in the long term.
# 4. Often what we learned is confusing.  Discuss if there are contradictory results how that might have happened
#    >Some results that contradicts with what we expected is that for Japanese IPs, creation date and media exposure did not matter as much; average search interests matters the most. Our explanation for this is that Japanese franchises often keep fans engaged through many forms of media and fan culture, such as manga releases, merchandise, games, and active online communities. Many Japanese series also run for long periods of time or continue through different formats, which helps the interest level in the franchise consistent over time. Cultural differences in the entertainment industry may also explain this result. In Japan, IPs often begin as manga or light novels and later expand into anime, movies, games, and merchandise. Because new content and products are released regularly, fans continue to search for updates and interact with the franchise. This ongoing engagement may be why search interest better reflects the popularity and revenue potential of Japanese IPs.
# 5. Discuss the limitations of your work. e.g, is the dataset a biased sample? would more data make you more confident? would longitudinal instead of cross-sectional data helpful? is there evidence that the phenomena you're investigating may change over time? etc
# >TMDb API: There are some important limitations to this dataset. The data was collected through many API searches rather than downloaded as a single dataset, so it depends on how complete and accurate TMDb’s information is. Some search results may include titles that are only loosely related to an IP, which adds noise to the data. In addition, streaming provider information is missing for some IPs, especially non-U.S. content. For example, Rilakkuma and Kumamon have limited provider data in TMDb even though it is available on major streaming platforms. Because of this, the accessibility of some IPs may be underestimated, and the results should be viewed as general comparisons instead of exact measurements.
# We only used 27 IPs from each country because there is only a maximum of 27 Japanese IPs on the Wikipedia dataset.
#
# 6. If you would like, you can also say what the next steps in this investigation might be if the work was to continue outside this class
# > Future research could improve this study by including more IPs and additional measures of engagement and media exposure. It would also be more informational to add other factors such as merchandise sales and social media activity. Future research could also expand to other international markets like China, or other major entertainment markets. These additions may help explain why some entertainment IPs become more financially successful than others.
